# %%
from netCDF4 import Dataset
import numpy as np

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-232127951180> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 from mpl_toolkits.basemap import Basemap
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
nc = Dataset('../../measurements/bathymetry/erie_lld.grd')

# %%
topo = -nc.variables['z'][:] #[::10,::10]
x = nc.variables['x'][:] #[::10]
y = nc.variables['y'][:] #[::10]
lon_0 = x.mean()
lat_0 = y.mean()
lon, lat = np.meshgrid(x, y)
x, y = m(lon, lat)


levels1 = np.linspace(0,70,14*2+1)
levels2 = np.linspace(0,70,14+1)
# levels2 = np.linspace(-10,0,14*2+1)
plt.figure(figsize=(12,6), dpi=300)
m = Basemap(width=500000*0.8,height=300000*0.8, resolution='f',projection='stere',lat_0=lat_0+0.2,lon_0=lon_0-0.2)
# m.shadedrelief()
# m.drawstates()
# m.drawrivers()
m.drawcoastlines()
m.drawparallels(np.arange(41., 44, 1.),labels=[1,0,0,0], fontsize=10)
m.drawmeridians(np.arange(-84., -78., 1.),labels=[0,0,1,0], fontsize=10)
# cs = m.pcolor(x,y,np.squeeze(topo), cmap=cmocean.cm.deep)
# ax.set_ylim(*[41,43])
cax = m.contourf(x,y,topo, levels=levels1,cmap=cmocean.cm.deep)
plt.contour(x,y,topo, levels=levels1, colors='k')  # negative contours will be dashed by default
                 
# c = m.contourf(x,y,topo, levels=levels2,cmap=cmocean.cm.solar)
cbar = m.colorbar(cax,location='bottom')

# cbar = m.colorbar(cs, location='bottom')
cbar.set_label('Depth, m')
plt.show()
# plt.savefig('Bathymetry.png')

# %%
# nc = Dataset('erie_lld.grd')

# # examine the variables
# # print(nc.variables.keys())
# # print(nc.variables['z'])

# # sample every 10th point of the 'z' variable
# # topo = nc.variables['z'][::10,::10]
# topo = -nc.variables['z'][::10,::10]
# x = nc.variables['x'][::10]
# y = nc.variables['y'][::10]

# # make image
# plt.figure(figsize=(10,10))
# # cax = plt.imshow(topo,origin='lower', vmin=-10, vmax=70, cmap=cmocean.cm.deep)
# levels = np.linspace(0,70,14*2+1)
# cax = plt.contourf(x,y,topo, levels=levels,cmap=cmocean.cm.deep)
# plt.colorbar(cax, orientation='horizontal')
# plt.axes().set_aspect('equal', 'datalim')
# plt.ylim(41.0,43.0)
# plt.title(nc.title)

# # plt.savefig('image.png', bbox_inches=0)

# plt.show()

# %%
import matplotlib.pyplot as plt

# %%
import gdal

# %%
raster = gdal.Open('ice/grid2011/g20110202.ct')
band = raster.GetRasterBand(1)
array = band.ReadAsArray()
plt.imshow(array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-95a0c0a14654> in <module>()
#       4 band = raster.GetRasterBand(1)
#       5 array = band.ReadAsArray()
# ----> 6 plt.imshow(array)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3027                         filternorm=filternorm, filterrad=filterrad,
#    3028                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3029                         **kwargs)
#    3030     finally:
#    3031         ax.hold(washold)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    4920                               resample=resample, **kwargs)
#    4921
# -> 4922         im.set_data(X)
#    4923         im.set_alpha(alpha)
#    4924         if im.get_clip_path() is None:
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/image.py in set_data(self, A)
#     447         if (self._A.dtype != np.uint8 and
#     448                 not np.can_cast(self._A.dtype, np.float)):
# --> 449             raise TypeError("Image data can not convert to float")
#     450
#     451         if (self._A.ndim not in (2, 3) or
#
# TypeError: Image data can not convert to float

# %%
band
# Out:
# <osgeo.gdal.Band; proxy of <Swig Object of type 'GDALRasterBandShadow *' at 0x106b194e0> >

# %%
x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-96341d27d773> in <module>()
# ----> 1 plt.imshow(array)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3027                         filternorm=filternorm, filterrad=filterrad,
#    3028                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3029                         **kwargs)
#    3030     finally:
#    3031         ax.hold(washold)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    4920                               resample=resample, **kwargs)
#    4921
# -> 4922         im.set_data(X)
#    4923         im.set_alpha(alpha)
#    4924         if im.get_clip_path() is None:
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/image.py in set_data(self, A)
#     447         if (self._A.dtype != np.uint8 and
#     448                 not np.can_cast(self._A.dtype, np.float)):
# --> 449             raise TypeError("Image data can not convert to float")
#     450
#     451         if (self._A.ndim not in (2, 3) or
#
# TypeError: Image data can not convert to float
