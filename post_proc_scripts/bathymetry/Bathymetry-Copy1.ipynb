# %%
from netCDF4 import Dataset
import numpy as np

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %matplotlib inline

# %%
nc = Dataset('../../measurements/bathymetry/erie_lld.grd')

# %%
import cmocean
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):

# %%
topo = -nc.variables['z'][:] #[::10,::10]
x = nc.variables['x'][:] #[::10]
y = nc.variables['y'][:] #[::10]
lon_0 = x.mean()
lat_0 = y.mean()
lon, lat = np.meshgrid(x, y)
m = Basemap(width=500000*0.8,height=300000*0.8, resolution='h',projection='stere',lat_0=lat_0+0.2,lon_0=lon_0-0.2)
x, y = m(lon, lat)
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less_equal
#   """Entry point for launching an IPython kernel.
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.

# %%
levels1 = np.linspace(0,70,14*2+1)
levels2 = np.linspace(0,70,14+1)
# levels2 = np.linspace(-10,0,14*2+1)
f, ax = plt.subplots(1,1, figsize=(12,6), dpi=90)

# m.shadedrelief()
# m.drawstates()
# m.drawrivers()
m.drawcoastlines()
m.drawparallels(np.arange(41., 44, 1.),labels=[1,0,0,0], fontsize=10)
m.drawmeridians(np.arange(-84., -78., 1.),labels=[0,0,1,0], fontsize=10)
# m.fillcontinents(color='#ffe2ab')
# cs = m.pcolor(x,y,np.squeeze(topo))
# ax.set_ylim(*[41,43])
cax = m.contourf(x,y,topo, levels=levels1)
# plt.contour(x,y,topo, levels=levels1, colors='k')  # negative contours will be dashed by default

# ax.scatter([80+180,81+180],[40,43.0], color='k')      


# cbar = m.colorbar(cs, location='bottom')
# cbar.set_label('Depth, m')
plt.show()
# plt.savefig('Bathymetry.png')

# %%
# nc = Dataset('erie_lld.grd')
topo = -nc.variables['z'][:] #[::10,::10]
x = nc.variables['x'][:] #[::10]
y = nc.variables['y'][:] #[::10]
lon_0 = x.mean()
lat_0 = y.mean()
lon, lat = np.meshgrid(x, y)
m = Basemap(width=500000*0.8,height=300000*0.8, resolution='h',projection='stere',lat_0=lat_0+0.2,lon_0=lon_0-0.2)
x, y = m(lon, lat)
levels1 = np.linspace(0,70,14*2+1)
levels2 = np.linspace(0,70,14+1)
f, ax = plt.subplots(1,1, figsize=(12,6), dpi=90)
m.drawcoastlines()
m.drawparallels(np.arange(41., 44, 1.),labels=[1,0,0,0], fontsize=10)
m.drawmeridians(np.arange(-84., -78., 1.),labels=[0,0,1,0], fontsize=10)
cax = m.contourf(x,y,topo, levels=levels1)
plt.show()
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in less_equal
#
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in greater

# %%
ax.get_ylim()
# Out:
# (0.0, 240000.0000000005)

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import gdal

# %%
# raster = gdal.Open('ice/grid2011/g20110202.ct')
# band = raster.GetRasterBand(1)
# array = band.ReadAsArray()
# plt.imshow(array)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-95a0c0a14654> in <module>()
#       2
#       3 raster = gdal.Open('ice/grid2011/g20110202.ct')
# ----> 4 band = raster.GetRasterBand(1)
#       5 array = band.ReadAsArray()
#       6 plt.imshow(array)
#
# AttributeError: 'NoneType' object has no attribute 'GetRasterBand'

# %%
c={}
import numpy as np
from osgeo import gdal
ds = gdal.Open("../../measurements/bathymetry/central.tif")
x = np.array(ds.GetRasterBand(1).ReadAsArray())
pos = x[x>0]
for d in np.linspace(0,64.5,65/0.5):
    neg = x[x<-d]
    c[d] = -neg.sum(axis=0)/0.5
c
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:7: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
# {0.0: 91595744.0,
#  0.5: 91590576.0,
#  1.0: 91569136.0,
#  1.5: 91551384.0,
#  2.0: 91529728.0,
#  2.5: 91504920.0,
#  3.0: 91475160.0,
#  3.5: 91438176.0,
#  4.0: 91395456.0,
#  4.5: 91344384.0,
#  5.0: 91280944.0,
#  5.5: 91208088.0,
#  6.0: 91106296.0,
#  6.5: 90999264.0,
#  7.0: 90847008.0,
#  7.5: 90654912.0,
#  8.0: 90435120.0,
#  8.5: 90200832.0,
#  9.0: 89880576.0,
#  9.5: 89521496.0,
#  10.0: 88979400.0,
#  10.5: 88483912.0,
#  11.0: 87634432.0,
#  11.5: 86570672.0,
#  12.0: 85193464.0,
#  12.5: 83913632.0,
#  13.0: 82309744.0,
#  13.5: 80934392.0,
#  14.0: 79251048.0,
#  14.5: 77833640.0,
#  15.0: 76432248.0,
#  15.5: 74903264.0,
#  16.0: 73270792.0,
#  16.5: 71451760.0,
#  17.0: 69314880.0,
#  17.5: 66707092.0,
#  18.0: 64211384.0,
#  18.5: 61514864.0,
#  19.0: 58156340.0,
#  19.5: 52280204.0,
#  20.0: 46895704.0,
#  20.5: 39887812.0,
#  21.0: 33338192.0,
#  21.5: 20598596.0,
#  22.0: 12724782.0,
#  22.5: 10737733.0,
#  23.0: 5283979.0,
#  23.5: 4031520.0,
#  24.0: 52864.1328125,
#  24.5: 34660.23046875,
#  25.0: 19105.09765625,
#  25.5: 6217.869140625,
#  26.0: -0.0,
#  26.5: -0.0,
#  27.0: -0.0,
#  27.5: -0.0,
#  28.0: -0.0,
#  28.5: -0.0,
#  29.0: -0.0,
#  29.5: -0.0,
#  30.0: -0.0,
#  30.5: -0.0,
#  31.0: -0.0,
#  31.5: -0.0,
#  32.0: -0.0,
#  32.5: -0.0,
#  33.0: -0.0,
#  33.5: -0.0,
#  34.0: -0.0,
#  34.5: -0.0,
#  35.0: -0.0,
#  35.5: -0.0,
#  36.0: -0.0,
#  36.5: -0.0,
#  37.0: -0.0,
#  37.5: -0.0,
#  38.0: -0.0,
#  38.5: -0.0,
#  39.0: -0.0,
#  39.5: -0.0,
#  40.0: -0.0,
#  40.5: -0.0,
#  41.0: -0.0,
#  41.5: -0.0,
#  42.0: -0.0,
#  42.5: -0.0,
#  43.0: -0.0,
#  43.5: -0.0,
#  44.0: -0.0,
#  44.5: -0.0,
#  45.0: -0.0,
#  45.5: -0.0,
#  46.0: -0.0,
#  46.5: -0.0,
#  47.0: -0.0,
#  47.5: -0.0,
#  48.0: -0.0,
#  48.5: -0.0,
#  49.0: -0.0,
#  49.5: -0.0,
#  50.0: -0.0,
#  50.5: -0.0,
#  51.0: -0.0,
#  51.5: -0.0,
#  52.0: -0.0,
#  52.5: -0.0,
#  53.0: -0.0,
#  53.5: -0.0,
#  54.0: -0.0,
#  54.5: -0.0,
#  55.0: -0.0,
#  55.5: -0.0,
#  56.0: -0.0,
#  56.5: -0.0,
#  57.0: -0.0,
#  57.5: -0.0,
#  58.0: -0.0,
#  58.5: -0.0,
#  59.0: -0.0,
#  59.5: -0.0,
#  60.0: -0.0,
#  60.5: -0.0,
#  61.0: -0.0,
#  61.5: -0.0,
#  62.0: -0.0,
#  62.5: -0.0,
#  63.0: -0.0,
#  63.5: -0.0,
#  64.0: -0.0,
#  64.5: -0.0}

# %%
depths[::-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8b5b40a44bd5> in <module>()
# ----> 1 depths[::-1]
#
# NameError: name 'depths' is not defined

# %%
e_vol=np.array([])
import numpy as np
import gdal
ds = gdal.Open("../../measurements/bathymetry/erie_lld.tif")
x = np.array(ds.GetRasterBand(1).ReadAsArray())
pos = x[x>0]
neg = x[x<0]
e = neg.sum(axis=0)
depths = np.linspace(0,63,63.5/0.5)
prev_volume_below_d = 0
for d in depths:
    neg = x[x<=-d]+d
    e_vol = np.append(e_vol,  -neg.sum()*(111.32*0.85*0.0008333333*1000)**2 )
# e_vol = np.array(e_vol)[1:]-np.array(e_vol)[:-1]
# e_vol
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:9: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
e_vol[0]/0.5*1e-9

# %%
e_vol.sum()*1e-9
# Out:
# 10846.492564799159

# %%
plt.semilogy(depths, e_vol)

# %%
plt.plot(depths[:-1], -np.diff(e_vol)/0.5)

# %% [markdown]
# ### This is the volume of layers of lake Erie (eastern basin) with 0.5 step in depth np.linspace(0,63,63.5/0.5)

# %%
e_vol=np.array([])
import numpy as np
import gdal
ds = gdal.Open("../../measurements/bathymetry/eastern.tif")
x = np.array(ds.GetRasterBand(1).ReadAsArray())
pos = x[x>0]
neg = x[x<0]
e = neg.sum(axis=0)
depths = np.linspace(0,63.0,127)
prev_volume_below_d = 0
for d in depths:
    neg = x[x<=-d]+d
    e_vol = np.append(e_vol,  -neg.sum()*(111.32*0.85*0.0008333333*1000)**2 )
# e_vol = np.array(e_vol)[1:]-np.array(e_vol)[:-1]
# e_vol

# %%
e_vol/0.5
# Out:
# array([ 3.36040888e+11,  3.29130142e+11,  3.22292962e+11,  3.15484060e+11,
#         3.08706868e+11,  3.01954869e+11,  2.95236047e+11,  2.88546299e+11,
#         2.81894553e+11,  2.75276779e+11,  2.68705886e+11,  2.62174786e+11,
#         2.55693774e+11,  2.49254570e+11,  2.42871075e+11,  2.36537371e+11,
#         2.30283948e+11,  2.24100634e+11,  2.18002452e+11,  2.11965923e+11,
#         2.06001195e+11,  2.00093930e+11,  1.94252981e+11,  1.88468339e+11,
#         1.82759142e+11,  1.77114918e+11,  1.71551336e+11,  1.66058846e+11,
#         1.60690968e+11,  1.55412090e+11,  1.50248995e+11,  1.45173692e+11,
#         1.40224606e+11,  1.35385149e+11,  1.30717397e+11,  1.26180786e+11,
#         1.21849567e+11,  1.17651789e+11,  1.13646259e+11,  1.09755506e+11,
#         1.06026771e+11,  1.02406855e+11,  9.89250266e+10,  9.55467329e+10,
#         9.22794854e+10,  8.90940737e+10,  8.60454612e+10,  8.30763220e+10,
#         8.01782373e+10,  7.73326353e+10,  7.45515655e+10,  7.18295566e+10,
#         6.92016757e+10,  6.66331168e+10,  6.41335607e+10,  6.16974923e+10,
#         5.93256702e+10,  5.70115659e+10,  5.47602593e+10,  5.25691886e+10,
#         5.04318534e+10,  4.83416631e+10,  4.63012662e+10,  4.43107655e+10,
#         4.23725609e+10,  4.04877094e+10,  3.86555985e+10,  3.68742853e+10,
#         3.51450351e+10,  3.34682395e+10,  3.18451949e+10,  3.02748351e+10,
#         2.87549900e+10,  2.72839032e+10,  2.58653037e+10,  2.45010273e+10,
#         2.31866376e+10,  2.19176518e+10,  2.06976171e+10,  1.95190040e+10,
#         1.83839077e+10,  1.72949925e+10,  1.62565346e+10,  1.52639889e+10,
#         1.43199171e+10,  1.34192968e+10,  1.25643656e+10,  1.17530019e+10,
#         1.09986993e+10,  1.02918135e+10,  9.62414672e+09,  8.99077224e+09,
#         8.39407528e+09,  7.83111028e+09,  7.30310598e+09,  6.80496008e+09,
#         6.33645923e+09,  5.88764792e+09,  5.45909584e+09,  5.04957111e+09,
#         4.66058502e+09,  4.28698900e+09,  3.92841233e+09,  3.58467937e+09,
#         3.25498513e+09,  2.93736486e+09,  2.63256914e+09,  2.34078740e+09,
#         2.06361777e+09,  1.80153219e+09,  1.56129268e+09,  1.34033603e+09,
#         1.14122176e+09,  9.58790151e+08,  7.93653720e+08,  6.46228955e+08,
#         5.19318236e+08,  4.06779052e+08,  3.11807168e+08,  2.28594753e+08,
#         1.59634111e+08,  1.01941578e+08,  5.88009020e+07,  2.70902418e+07,
#         8.78996181e+06,  2.86866932e+03, -0.00000000e+00])

# %%
(20/5787+290/6357+170/6237)/60/60/24/365*1e+9
# Out:
# 0.10958974247024221

# %%
(e_vol[0]-e_vol[1])/0.5*1e-6
# Out:
# 2745.1756228150402

# %%
290/0.0183
# Out:
# 15846.994535519125

# %%
20/0.0074
# Out:
# 2702.7027027027025

# %%
170/0.024
# Out:
# 7083.333333333333

# %%
5780 + 6360 + 6240
# Out:
# 18380

# %%
tau = 2.4
z_av = 19
sigma = 8/z_av
tau/(1 + tau*sigma)
# Out:
# 1.1937172774869111

# %%
tau = 2.4
z_av = 19
sigma = 8/z_av
TP =

# %%
# Out:
# 0.0902439024390244

# %%
plt.plot(depths, e_vol)

# %%
plt.semilogy(depths[1:], -np.diff(e_vol)/0.5 )

# %%
(-np.diff(e_vol)).sum()*1e-9
# Out:
# 284.7521297217806

# %%
e_vol=np.array([])
import numpy as np
import gdal
ds = gdal.Open("../../measurements/bathymetry/western.tif")
x = np.array(ds.GetRasterBand(1).ReadAsArray())
pos = x[x>0]
neg = x[x<0]
e = neg.sum(axis=0)
depths = np.linspace(0,63.0,127)
prev_volume_below_d = 0
for d in depths:
    neg = x[x<-d]
    e_vol = np.append(e_vol,  -neg.sum(axis=0)*0.75*(111.32*0.0008333333*1000)**2 )
# e_vol = np.array(e_vol)[1:]-np.array(e_vol)[:-1]
# e_vol

# %%
plt.semilogy(depths, e_vol)

# %%
plt.plot(depths[1:], -np.diff(e_vol) )

# %%
dataset = ds

# %%
c+e+w

# %%
import numpy as np
from osgeo import gdal
ds = gdal.Open("../../measurements/bathymetry/erie_lld.tif")
x = np.array(ds.GetRasterBand(1).ReadAsArray())
pos = x[x>0]
neg = x[x<0]
pos.sum(axis=0)
neg.sum(axis=0)

# %%
(x<=0).sum()

# %%
dataset=ds

# %%
band = dataset.GetRasterBand(1)
print("Band Type={}".format(gdal.GetDataTypeName(band.DataType)))
      
min = band.GetMinimum()
max = band.GetMaximum()
if not min or not max:
    (min,max) = band.ComputeRasterMinMax(True)
print("Min={:.3f}, Max={:.3f}".format(min,max))
      
if band.GetOverviewCount() > 0:
    print("Band has {} overviews".format(band.GetOverviewCount()))
      
if band.GetRasterColorTable():
    print("Band has a color table with {} entries".format(band.GetRasterColorTable().GetCount()))

# %%
print("Driver: {}/{}".format(dataset.GetDriver().ShortName,
                             dataset.GetDriver().LongName))
print("Size is {} x {} x {}".format(dataset.RasterXSize,
                                    dataset.RasterYSize,
                                    dataset.RasterCount))
print("Projection is {}".format(dataset.GetProjection()))
geotransform = dataset.GetGeoTransform()
if geotransform:
    print("Origin = ({}, {})".format(geotransform[0], geotransform[3]))
    print("Pixel Size = ({}, {})".format(geotransform[1], geotransform[5]))

# %%
e*1e-9*0.75*(111.32*0.0008333333*1000)**2

# %%
scanline = band.ReadRaster(xoff=0, yoff=0,
                           xsize=band.XSize, ysize=1,
                           buf_xsize=band.XSize, buf_ysize=1,
                           buf_type=gdal.GDT_Float32)

# %%
import struct
tuple_of_floats = struct.unpack('f' * band.XSize, scanline)

# %%
print('{:.8f}'.format((np.array(tuple_of_floats) - tuple_of_floats[0])[4]))

# %% [markdown]
# ### Lake Ontario

# %%
import numpy as np
from osgeo import gdal
ds = gdal.Open("../../measurements/bathymetry/ontario_lld.tif")
x = np.array(ds.GetRasterBand(1).ReadAsArray())
pos = x[x>0]
neg = x[x<0]
pos.sum(axis=0)
neg.sum(axis=0)

# %%
dataset=ds

# %%
band = dataset.GetRasterBand(1)
print("Band Type={}".format(gdal.GetDataTypeName(band.DataType)))
      
min = band.GetMinimum()
max = band.GetMaximum()
if not min or not max:
    (min,max) = band.ComputeRasterMinMax(True)
print("Min={:.3f}, Max={:.3f}".format(min,max))
      
if band.GetOverviewCount() > 0:
    print("Band has {} overviews".format(band.GetOverviewCount()))
      
if band.GetRasterColorTable():
    print("Band has a color table with {} entries".format(band.GetRasterColorTable().GetCount()))

# %%
print("Driver: {}/{}".format(dataset.GetDriver().ShortName,
                             dataset.GetDriver().LongName))
print("Size is {} x {} x {}".format(dataset.RasterXSize,
                                    dataset.RasterYSize,
                                    dataset.RasterCount))
print("Projection is {}".format(dataset.GetProjection()))
geotransform = dataset.GetGeoTransform()
if geotransform:
    print("Origin = ({}, {})".format(geotransform[0], geotransform[3]))
    print("Pixel Size = ({}, {})".format(geotransform[1], geotransform[5]))

# %%
e_vol=np.array([])
import numpy as np
import gdal
ds = gdal.Open("../../measurements/bathymetry/ontario_lld.grd")
x = np.array(ds.GetRasterBand(1).ReadAsArray())
pos = x[x>0]
neg = x[x<0]
depths = np.linspace(0,250,501)
for d in depths:
    neg = x[x<=-d]+d
    e_vol = np.append(e_vol,  -neg.sum()*(111.32*0.85*0.0008333333*1000)**2 )
# e_vol = np.array(e_vol)[1:]-np.array(e_vol)[:-1]
# e_vol

# %%
-np.diff(e_vol)/0.5
