# %%
# %matplotlib inline
import statsmodels.formula.api as sm

# %%
# %run ploting.py
# Out:
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py:50: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df = df.convert_objects(convert_numeric=True)

# %%
df.head()
# Out:
#                   WDIR      WSPD       GST      WVHT       DPD       APD  MWD  \
# YY_MM_DD
# 1980-06-23   74.400000  2.740000  3.600000  0.060000  2.480000  2.420000  NaN
# 1980-06-24  116.291667  1.529167  2.075000  0.187500  2.650000  2.583333  NaN
# 1980-06-25  124.833333  2.137500  2.575000  0.036364  2.913636  2.590909  NaN
# 1980-06-26  174.083333  2.141667  2.554167  0.100000  2.658333  2.425000  NaN
# 1980-06-27  128.833333  2.633333  3.754167  0.341667  2.704167  2.612500  NaN
#
#                    PRES       ATMP       WTMP  DEWP  VIS TIDE
# YY_MM_DD
# 1980-06-23  1016.740000  21.340000  19.900000   NaN  NaN  NAN
# 1980-06-24  1016.975000  19.966667  18.841667   NaN  NaN  NAN
# 1980-06-25  1016.937500  20.479167  19.587500   NaN  NaN  NAN
# 1980-06-26  1013.933333  22.233333  20.579167   NaN  NaN  NAN
# 1980-06-27  1014.325000  21.916667  21.558333   NaN  NaN  NAN

# %%
df
# Out:
#                   WDIR      WSPD        GST      WVHT       DPD       APD  \
# YY_MM_DD
# 1980-06-23   74.400000  2.740000   3.600000  0.060000  2.480000  2.420000
# 1980-06-24  116.291667  1.529167   2.075000  0.187500  2.650000  2.583333
# 1980-06-25  124.833333  2.137500   2.575000  0.036364  2.913636  2.590909
# 1980-06-26  174.083333  2.141667   2.554167  0.100000  2.658333  2.425000
# 1980-06-27  128.833333  2.633333   3.754167  0.341667  2.704167  2.612500
# 1980-06-28  147.625000  3.616667   4.875000  0.445833  2.916667  2.754167
# 1980-06-29  225.875000  4.141667   5.583333  0.583333  3.150000  3.008333
# 1980-06-30  294.833333  6.400000   8.504167  0.920833  3.366667  3.112500
# 1980-07-01  230.416667  2.612500   3.650000  0.370833  2.658333  2.608333
# 1980-07-02  125.000000  2.979167   3.925000  0.437500  2.891667  2.708333
# 1980-07-03   76.333333  2.091667   2.900000  0.316667  2.816667  2.670833
# ...

# %%
df2 = df.reset_index()

# %%
df2.head()
df2.sort_values(by='YY_MM_DD')
df2['range'] = range(0, len(df2))

# %%
result = sm.ols(formula="ATMP ~ range", data=df2).fit()

# %%
result.params
# Out:
# Intercept    11.178656
# range        -0.000081
# dtype: float64

# %%
result.plot()
# Out:
# ---------------------------------------------------
# AttributeError    Traceback (most recent call last)
# <ipython-input-40-80407163cc91> in <module>()
# ----> 1 result.plot()
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/statsmodels/base/wrapper.py in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'OLSResults' object has no attribute 'plot'

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std
prstd, iv_l, iv_u = wls_prediction_std(result);

df['1980': '2017'].plot(y='ATMP', color='k')
x = df['1980': '2017'].index.to_pydatetime()[:-1]
x.sort()
plt.plot(x, result.fittedvalues.values, 'r--.')
plt.plot(x, iv_u.values, 'r--');
plt.plot(x, iv_l.values, 'r--');

# %%
df.index.to_pydatetime()
# Out:
# datetime.datetime(1980, 6, 23, 0, 0)

# %%
iv_l.values
# Out:
# array([-8.49101199, -8.49109182, -8.49117164, ..., -9.49796199,
#        -9.49804333, -9.49812467])

# %%
result.fittedvalues.values
# Out:
# array([ 11.17865649,  11.17857591,  11.17849533, ...,  10.17170348,
#         10.1716229 ,  10.17154231])

# %%
df.index.values
# Out:
# array(['1980-06-22T20:00:00.000000000-0400',
#        '1980-06-23T20:00:00.000000000-0400',
#        '1980-06-24T20:00:00.000000000-0400', ...,
#        '2015-12-28T19:00:00.000000000-0500',
#        '2015-12-29T19:00:00.000000000-0500',
#        '2015-12-30T19:00:00.000000000-0500'], dtype='datetime64[ns]')

# %%
plt.plot(df.index.values, iv_l.values)
# Out:
# ---------------------------------------------------
# ValueError        Traceback (most recent call last)
# <ipython-input-82-ca68a3f84411> in <module>()
# ----> 1 plt.plot(df.index.values, iv_l.values)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
# ...

# %%
df.index.values[:-2].size
# Out:
# 12497

# %%
len(iv_l.values)
# Out:
# 12497

# %%
plt.plot(iv_u.values)

# %%
df.index.values[:-2]
# Out:
# array(['1980-06-22T20:00:00.000000000-0400',
#        '1980-06-23T20:00:00.000000000-0400',
#        '1980-06-24T20:00:00.000000000-0400', ...,
#        '2015-12-26T19:00:00.000000000-0500',
#        '2015-12-27T19:00:00.000000000-0500',
#        '2015-12-28T19:00:00.000000000-0500'], dtype='datetime64[ns]')

# %%
x.sort
# Out:
# <function ndarray.sort>

# %%
x.sort()

# %%
x.size
# Out:
# 12498

# %%
max(df['ATMP'])
# Out:
# 30.103544759999998

# %%
result.summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   ATMP   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     10.49
# Date:                Tue, 31 Jan 2017   Prob (F-statistic):            0.00120
# Time:                        12:38:21   Log-Likelihood:                -46548.
# No. Observations:               12497   AIC:                         9.310e+04
# Df Residuals:                   12495   BIC:                         9.312e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     11.1787      0.180     62.266      0.000        10.827    11.531
# ...

# %%
result.params[0]
# Out:
# 11.178656494701357
