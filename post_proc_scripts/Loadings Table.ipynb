# %%
import pandas as pd

# %%
print(pd.read_csv('/Users/imarkelo/Google Drive/GDocuments/Lake Erie/Draft/Rivers_tables/Total loads.csv').to_latex())
# Out:
# \begin{tabular}{llrrrrrrrrrrrrrrr}
# \toprule
# {} &                     Clinton (Michigan, US) &    59.3 &   119.5 &    83.8 &      98 &   102.7 &    104.7 &    189.5 &     85.6 &    145.7 &    101.9 &    118.6 &    120.7 &     99.1 &     93.9 &    139.2 \\
# \midrule
# 0  &                       Belle (Michigan, US) &     3.3 &     8.6 &     7.4 &     6.1 &    10.1 &     9.30 &    20.20 &     6.40 &    16.30 &    10.00 &    11.00 &    14.70 &    12.40 &    17.40 &    23.90 \\
# 1  &                       Black (Michigan, US) &     4.8 &    45.3 &    86.8 &    25.3 &   119.4 &    76.30 &   213.80 &    11.90 &    36.00 &    69.60 &    41.40 &     9.50 &    30.70 &    20.90 &    13.90 \\
# 2  &                                      Total &    67.4 &   173.4 &   178.0 &   129.4 &   232.2 &   190.30 &   423.50 &   103.90 &   198.00 &   181.50 &   171.00 &   144.90 &   142.20 &   132.20 &   177.00 \\
# ...
