# %%
# %matplotlib inline
import statsmodels.formula.api as sm

# %%
plt.close()

# %%
# %run ploting.py
# Out:
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py:90: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df = df.convert_objects(convert_numeric=True)
# Buffalocreek, Eastern
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     305                 pass
#     306             else:
# --> 307                 return printer(obj)
#     308             # Finally look for special method names
#     309             method = get_real_method(obj, self.print_method)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     225
#     226     if 'png' in formats:
# --> 227         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     228     if 'retina' in formats or 'png2x' in formats:
#     229         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     117
#     118     bytes_io = BytesIO()
# --> 119     fig.canvas.print_figure(bytes_io, **kw)
#     120     data = bytes_io.getvalue()
#     121     if fmt == 'svg':
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2190                     orientation=orientation,
#    2191                     dryrun=True,
# -> 2192                     **kwargs)
#    2193                 renderer = self.figure._cachedRenderer
#    2194                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1141
#    1142             mimage._draw_list_compositing_images(
# -> 1143                 renderer, self, dsu, self.suppressComposite)
#    1144
#    1145             renderer.close_group('figure')
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2407             renderer.stop_rasterizing()
#    2408
# -> 2409         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2410
#    2411         renderer.close_group('axes')
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1134         renderer.open_group(__name__)
#    1135
# -> 1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1138                                                                 renderer)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#     967
#     968         interval = self.get_view_interval()
# --> 969         tick_tups = [t for t in self.iter_ticks()]
#     970         if self._smart_bounds:
#     971             # handle inverted limits
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in <listcomp>(.0)
#     967
#     968         interval = self.get_view_interval()
# --> 969         tick_tups = [t for t in self.iter_ticks()]
#     970         if self._smart_bounds:
#     971             # handle inverted limits
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in iter_ticks(self)
#     910         Iterate through all of the major and minor ticks.
#     911         """
# --> 912         majorLocs = self.major.locator()
#     913         majorTicks = self.get_major_ticks(len(majorLocs))
#     914         self.major.formatter.set_locs(majorLocs)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in __call__(self)
#     981     def __call__(self):
#     982         'Return the locations of the ticks'
# --> 983         self.refresh()
#     984         return self._locator()
#     985
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in refresh(self)
#    1001     def refresh(self):
#    1002         'Refresh internal information based on current limits.'
# -> 1003         dmin, dmax = self.viewlim_to_dt()
#    1004         self._locator = self.get_locator(dmin, dmax)
#    1005
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#     758             vmin, vmax = vmax, vmin
#     759
# --> 760         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#     761
#     762     def _get_unit(self):
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in num2date(x, tz)
#     399         tz = _get_rc_timezone()
#     400     if not cbook.iterable(x):
# --> 401         return _from_ordinalf(x, tz)
#     402     else:
#     403         x = np.asarray(x)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in _from_ordinalf(x, tz)
#     252
#     253     ix = int(x)
# --> 254     dt = datetime.datetime.fromordinal(ix).replace(tzinfo=UTC)
#     255
#     256     remainder = float(x) - ix
#
# ValueError: ordinal must be >= 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py in <module>()
#     294
#     295 if __name__ == '__main__':
# --> 296     parsing_folders_with_names()
#     297     # df = plot_subplots_for_river_inputs()
#     298     # df = load_data('../measurements/weather/National_Buoy_Data_Center/basin_average/western_basin_average.csv')
#
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py in parsing_folders_with_names()
#     291         for river in files:
#     292             # print(river[:-12])
# --> 293             plot_subplots_for_river_inputs(basin, river[:-12])
#     294
#     295 if __name__ == '__main__':
#
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py in plot_subplots_for_river_inputs(basin, river)
#     280     # plt.tight_layout(pad=0, w_pad=0.5, h_pad=0)
#     281     plt.show()
# --> 282     fig.savefig('plots/rivers/' + basin + ' basin/' + river + '.png', dpi=300)
#     283     plt.close()
#     284     return df
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1570             self.set_frameon(frameon)
#    1571
# -> 1572         self.canvas.print_figure(*args, **kwargs)
#    1573
#    1574         if frameon:
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2242                 orientation=orientation,
#    2243                 bbox_inches_restore=_bbox_inches_restore,
# -> 2244                 **kwargs)
#    2245         finally:
#    2246             if bbox_inches and restore_bbox:
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     543
#     544     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 545         FigureCanvasAgg.draw(self)
#     546         renderer = self.get_renderer()
#     547         original_dpi = renderer.dpi
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1141
#    1142             mimage._draw_list_compositing_images(
# -> 1143                 renderer, self, dsu, self.suppressComposite)
#    1144
#    1145             renderer.close_group('figure')
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2407             renderer.stop_rasterizing()
#    2408
# -> 2409         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2410
#    2411         renderer.close_group('axes')
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1134         renderer.open_group(__name__)
#    1135
# -> 1136         ticks_to_draw = self._update_ticks(renderer)
#    1137         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1138                                                                 renderer)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#     967
#     968         interval = self.get_view_interval()
# --> 969         tick_tups = [t for t in self.iter_ticks()]
#     970         if self._smart_bounds:
#     971             # handle inverted limits
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in <listcomp>(.0)
#     967
#     968         interval = self.get_view_interval()
# --> 969         tick_tups = [t for t in self.iter_ticks()]
#     970         if self._smart_bounds:
#     971             # handle inverted limits
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/axis.py in iter_ticks(self)
#     910         Iterate through all of the major and minor ticks.
#     911         """
# --> 912         majorLocs = self.major.locator()
#     913         majorTicks = self.get_major_ticks(len(majorLocs))
#     914         self.major.formatter.set_locs(majorLocs)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in __call__(self)
#     981     def __call__(self):
#     982         'Return the locations of the ticks'
# --> 983         self.refresh()
#     984         return self._locator()
#     985
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in refresh(self)
#    1001     def refresh(self):
#    1002         'Refresh internal information based on current limits.'
# -> 1003         dmin, dmax = self.viewlim_to_dt()
#    1004         self._locator = self.get_locator(dmin, dmax)
#    1005
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#     758             vmin, vmax = vmax, vmin
#     759
# --> 760         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#     761
#     762     def _get_unit(self):
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in num2date(x, tz)
#     399         tz = _get_rc_timezone()
#     400     if not cbook.iterable(x):
# --> 401         return _from_ordinalf(x, tz)
#     402     else:
#     403         x = np.asarray(x)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/dates.py in _from_ordinalf(x, tz)
#     252
#     253     ix = int(x)
# --> 254     dt = datetime.datetime.fromordinal(ix).replace(tzinfo=UTC)
#     255
#     256     remainder = float(x) - ix
#
# ValueError: ordinal must be >= 1

# %%
'abc'.title()
# Out:
# 'Abc'

# %%
df.columns
# Out:
# Index(['inflowQ', 'inflowT', 'Susp', 'PO4a', 'PO4d', 'PO4c', 'PO4b', 'Chla',
#        'DOC', 'DIC', 'O2', 'NO3', 'NH4', 'SO4', 'Fe2', 'Ca2', 'pH', 'CH4',
#        'Fe3', 'Al3', 'Inflow concentration of dissolved silica [mg m-3]',
#        'IronSuspSed', 'IronUnfilRec', '*Iron, water, filtered [mg m-3]',
#        'SuspUnfil', 'num', 'TMP'],
#       dtype='object')

# %%
df2 = df.reset_index()

# %%
df2.head()
df2.sort_values(by='YY_MM_DD')
df2['range'] = range(0, len(df2))

# %%
result.params

# %%
result.plot()

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std
prstd, iv_l, iv_u = wls_prediction_std(result);

df['1980': '2017'].plot(y='ATMP', color='k')
x = df['1980': '2017'].index.to_pydatetime()[:-1]
x.sort()
plt.plot(x, result.fittedvalues.values, 'r--.')
plt.plot(x, iv_u.values, 'r--');
plt.plot(x, iv_l.values, 'r--');

# %%
df.index.to_pydatetime()

# %%
iv_l.values

# %%
result.fittedvalues.values

# %%
df.index.values

# %%
plt.plot(df.index.values, iv_l.values)

# %%
df.index.values[:-2].size

# %%
len(iv_l.values)

# %%
plt.plot(iv_u.values)

# %%
df.index.values[:-2]

# %%
x.sort

# %%
x.sort()

# %%
x.size

# %%
max(df['ATMP'])

# %%
result.summary

# %%
result.params[0]

# %%
df = load_data(r'../measurements/Excel Files/task 3/Maumee River/4193500.csv', encoding="ISO-8859-1")
df.rename(columns={r'*Phosphorus, water, unfiltered, as phosphorus [mg m-3]': 'inflowP'}, inplace=True)
plot_graphs(df, r'inflowP', r'Inflow P, unfiltered', 'mg/m3', lines=True)
# Out:
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py:80: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df = df.convert_objects(convert_numeric=True)

# %%
df.inflowP[df.inflowP > 3000] = 0
# Out:
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
plot_graphs(df, r'inflowP', r'Inflow P, unfiltered', 'mg/m3', lines=True, style='k-')
plt.savefig('plots/input/western/inflowP', r'Inflow P, unfiltered.png', dpi=150)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-fce961218796> in <module>()
#       1 plot_graphs(df, r'inflowP', r'Inflow P, unfiltered', 'mg/m3', lines=True, style='k-')
# ----> 2 plt.savefig('plots/input/western/inflowP', r'Inflow P, unfiltered.png', dpi=150)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     686 def savefig(*args, **kwargs):
#     687     fig = gcf()
# --> 688     res = fig.savefig(*args, **kwargs)
#     689     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     690     return res
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1563             self.set_frameon(frameon)
#    1564
# -> 1565         self.canvas.print_figure(*args, **kwargs)
#    1566
#    1567         if frameon:
#
# TypeError: print_figure() got multiple values for argument 'dpi'

# %%
result = linear_fit(df, 'inflowP')
prstd, iv_l, iv_u = wls_prediction_std(result)
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                inflowP   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     50.15
# Date:                Wed, 01 Feb 2017   Prob (F-statistic):           1.69e-12
# Time:                        08:42:07   Log-Likelihood:                -25863.
# No. Observations:                3827   AIC:                         5.173e+04
# Df Residuals:                    3825   BIC:                         5.174e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    311.3164      6.890     45.186      0.000       297.809   324.824
# num           -0.0193      0.003     -7.081      0.000        -0.025    -0.014
# ==============================================================================
# Omnibus:                     2457.184   Durbin-Watson:                   0.315
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30385.680
# Skew:                           2.929   Prob(JB):                         0.00
# Kurtosis:                      15.500   Cond. No.                     5.16e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.16e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
prstd
# Out:
# array([ 208.49250996,  208.49235263,  208.49227402, ...,  208.48749355,
#         208.48764639,  208.48772287])

# %%
result.params[1]*365
# Out:
# -7.0597939407384391
