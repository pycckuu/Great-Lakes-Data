# %%
# %matplotlib inline
# %matplotlib notebook
# %matplotlib nbagg
import statsmodels.formula.api as sm

# %%
df = find_all_csv_in_subfolders_and_create_single_df("../measurements/Excel Files/task 3/")
# Out:
# ploting.py:126: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df = df.convert_objects(convert_numeric=True, convert_dates=False)

# %%
sns.boxplot(x="j_day", y='O2', data=df, palette=sns.color_palette("Blues", 21), linewidth=0.5)

# %%
df = df.groupby(df.columns, axis=1).sum()

# %%
df = find_all_csv_in_subfolders_and_create_single_df("../measurements/Excel Files/task 3/Eastern Basin")
# Out:
# ploting.py:126: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df = df.convert_objects(convert_numeric=True, convert_dates=False)

# %%
df
# Out:
#         Al3    Ca2 Chla  DIC   DOC IronFilRec IronSuspSed IronUnfilRec   NH4  \
# 0       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 1       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 2       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 3       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 4       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 5       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 6       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 7       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 8       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 9       NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# 10      NaN    NaN  NaN  NaN   NaN        NaN         NaN          NaN   NaN
# ...

# %%
result.params

# %%
result.plot()

# %%
from statsmodels.sandbox.regression.predstd import wls_prediction_std
prstd, iv_l, iv_u = wls_prediction_std(result);

df['1980': '2017'].plot(y='ATMP', color='k')
x = df['1980': '2017'].index.to_pydatetime()[:-1]
x.sort()
plt.plot(x, result.fittedvalues.values, 'r--.')
plt.plot(x, iv_u.values, 'r--');
plt.plot(x, iv_l.values, 'r--');

# %%
df.index.to_pydatetime()

# %%
iv_l.values

# %%
result.fittedvalues.values

# %%
df.index.values

# %%
plt.plot(df.index.values, iv_l.values)

# %%
df.index.values[:-2].size

# %%
len(iv_l.values)

# %%
plt.plot(iv_u.values)

# %%
df.index.values[:-2]

# %%
x.sort

# %%
x.sort()

# %%
x.size

# %%
max(df['ATMP'])

# %%
result.summary

# %%
result.params[0]

# %%
df = load_data(r'../measurements/Excel Files/task 3/Maumee River/4193500.csv', encoding="ISO-8859-1")
df.rename(columns={r'*Phosphorus, water, unfiltered, as phosphorus [mg m-3]': 'inflowP'}, inplace=True)
plot_graphs(df, r'inflowP', r'Inflow P, unfiltered', 'mg/m3', lines=True)
# Out:
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py:80: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df = df.convert_objects(convert_numeric=True)

# %%
df.inflowP[df.inflowP > 3000] = 0
# Out:
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
plot_graphs(df, r'inflowP', r'Inflow P, unfiltered', 'mg/m3', lines=True, style='k-')
plt.savefig('plots/input/western/inflowP', r'Inflow P, unfiltered.png', dpi=150)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-fce961218796> in <module>()
#       1 plot_graphs(df, r'inflowP', r'Inflow P, unfiltered', 'mg/m3', lines=True, style='k-')
# ----> 2 plt.savefig('plots/input/western/inflowP', r'Inflow P, unfiltered.png', dpi=150)
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     686 def savefig(*args, **kwargs):
#     687     fig = gcf()
# --> 688     res = fig.savefig(*args, **kwargs)
#     689     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     690     return res
#
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1563             self.set_frameon(frameon)
#    1564
# -> 1565         self.canvas.print_figure(*args, **kwargs)
#    1566
# ...

# %%
result = linear_fit(df, 'inflowP')
prstd, iv_l, iv_u = wls_prediction_std(result)
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                inflowP   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     50.15
# Date:                Wed, 01 Feb 2017   Prob (F-statistic):           1.69e-12
# Time:                        08:42:07   Log-Likelihood:                -25863.
# No. Observations:                3827   AIC:                         5.173e+04
# Df Residuals:                    3825   BIC:                         5.174e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    311.3164      6.890     45.186      0.000       297.809   324.824
# ...

# %%
prstd
# Out:
# array([ 208.49250996,  208.49235263,  208.49227402, ...,  208.48749355,
#         208.48764639,  208.48772287])

# %%
result.params[1]*365
# Out:
# -7.0597939407384391

# %%
# %run -i ploting.py

# %% [markdown]
# # df['j_day'] = df['j_day'].apply(pd.to_numeric)

# %%
df['j_day'] = df['j_day'].apply(lambda x: datetime.timedelta(x)+datetime.date(2016, 12, 31))

# %%
ax=None

# %%
datetime.timedelta(1) + datetime.date(2016, 12, 31)
# Out:
# datetime.date(2017, 1, 1)

# %%
df1 = df[['river','j_day','inflowT','year']]
df1['j_day'] = df1['j_day'].apply(pd.to_numeric)
# Out:
# ploting.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # import matplotlib

# %%
df1 = df1.sort_values(['j_day', 'year'])
df2 = df1.interpolate(method='linear')

# %%
df3 = df2.pivot_table(index=['j_day'], columns=['year','river'])

# %%
df3 = df3.interpolate(axis=1)

# %%
df4 = df3.dropna(how='all')
df4
# Out:
#              inflowT                                                        \
# year            1980
# river ashtabulariver blackriver buffalocreek cattarauguscreek chagrinriver
# j_day
# 1                NaN        NaN          NaN              NaN          NaN
# 2                NaN   1.510526     1.605263         1.615789     1.521053
# 3                NaN   1.538462     1.884615         1.923077     1.576923
# 4                NaN   2.426316     2.663158         2.689474     2.452632
# 5                NaN   2.692105     2.621053         2.613158     2.684211
# 6                NaN   1.139474     1.494737         1.534211     1.178947
# 7                NaN   0.242857     0.434783         0.413043     0.285714
# 8                NaN   0.042105     0.421053         0.463158     0.084211
# 9                NaN   0.118421     0.284211         0.302632     0.136842
# 10               NaN   0.005263     0.052632         0.057895     0.010526
# ...

# %%
sns.tsplot([df4['inflowT'][c] for c in df4['inflowT'].columns])
plt.show()

# %%
sns.tsplot(data=df3, time='j_day', condition='river', value='inflowT')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/MarkelovIgor/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'river'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
sns.tsplot(df4.fillna(0).as_matrix().T)

# %%
df4.as_matrix().T
# Out:
# array([[        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,  1.51052632,  1.53846154, ...,  1.45      ,
#          2.12380952,  2.11904762],
#        [        nan,  1.60526316,  1.88461538, ...,  1.        ,
#          2.33809524,  4.09047619],
#        ...,
#        [ 1.72      ,  1.46      ,  3.1       , ...,  1.96      ,
#          1.16      ,  0.98      ],
#        [ 1.64      ,  1.32      ,  3.        , ...,  1.96      ,
#          1.16      ,  0.98      ],
#        [ 1.56      ,  1.18      ,  2.9       , ...,  1.96      ,
#          1.16      ,  0.98      ]])

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %run ploting.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py in <module>()
#     531 if __name__ == '__main__':
#     532     # pass
# --> 533     plotting_weather()
#     534     plot_total_amount_of_measurements(df)
#     535     plot_all_rivers_in_single_plot()
#
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py in plotting_weather()
#     211     """ plots weather for all 3 basins"""
#     212     for basin in ['eastern', 'central', 'western']:
# --> 213         plotting_weather_basin(basin)
#     214
#     215
#
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py in plotting_weather_basin(basin)
#     185     plt.close()
#     186     fig, axes = plt.subplots(2, 4, sharex='col', figsize=(20, 10), dpi=150)
# ...
