# %%
import glob
import pandas as pd
import datetime

# %%
Detroit_river = pd.read_csv('/Users/imarkelo/git/Great-Lakes-Data/measurements/Excel Files/task 3/Western Basin/detroitriver_average.csv', encoding='windows-1251')
Detroit_river['Year'] = pd.to_numeric(Detroit_river['Year'], errors='coerce')
Detroit_river['Month'] = pd.to_numeric(Detroit_river['Month'], errors='coerce')
Detroit_river['Day'] = pd.to_numeric(Detroit_river['Day'], errors='coerce')
Detroit_river['Inflow volume [m3 d-1]'] = pd.to_numeric(Detroit_river['Inflow volume [m3 d-1]'], errors='coerce')
Detroit_river[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'] = pd.to_numeric(Detroit_river[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'], errors='coerce')
Detroit_river = Detroit_river.dropna(subset=['Year', 'Month', 'Day', 'Inflow volume [m3 d-1]'])
Detroit_river['Date'] = Detroit_river.apply(lambda x:datetime.datetime.strptime("{0} {1} {2} 00:00:00".format(int(x['Year']),int(x['Month']), int(x['Day'])), "%Y %m %d %H:%M:%S"),axis=1)
Detroit_river = Detroit_river.groupby(['Date']).mean().reset_index()

Detroit_river[['Date','Inflow volume [m3 d-1]']].to_csv('proc_data/Flow_Detroit_River_data.csv', index=False)



Detroit_river = pd.read_csv('/Users/imarkelo/git/Great-Lakes-Data/measurements/Excel Files/task 3/Western Basin/detroitriver_average.csv', encoding='windows-1251')
Detroit_river['Year'] = pd.to_numeric(Detroit_river['Year'], errors='coerce')
Detroit_river['Month'] = pd.to_numeric(Detroit_river['Month'], errors='coerce')
Detroit_river['Day'] = pd.to_numeric(Detroit_river['Day'], errors='coerce')
Detroit_river = Detroit_river.dropna(subset=['Year', 'Month', 'Day', 'Inflow volume [m3 d-1]'])
Detroit_river['Date'] = Detroit_river.apply(lambda x:datetime.datetime.strptime("{0} {1} {2} 00:00:00".format(int(x['Year']),int(x['Month']), int(x['Day'])), "%Y %m %d %H:%M:%S"),axis=1)
Detroit_river[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'] = pd.to_numeric(Detroit_river[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'], errors='coerce')
Detroit_river = Detroit_river.dropna(subset=[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'])
Detroit_river[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'] = Detroit_river[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]']/1000
Detroit_river[['Date','Month',' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]']].to_csv('proc_data/TP_Detroit_River_data.csv', index=False)

# %%
Huron_river.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Inflow volume [m3 d-1]',
#        'Inflow temperature [°C]', '*Suspended sediment concentration [mg m-3]',
#        '*Orthophosphate, water, filtered, as phosphorus [mg m-3]',
#        '*Phosphorus, water, unfiltered,  as phosphorus [mg m-3]',
#        '*Phosphorus, water, filtered, as phosphorus [mg m-3]',
#        '*Orthophosphate, water, filtered, as PO4 [mg m-3]',
#        'Inflow concentration of chlorophyll-a (Chla-P) [mg m-3]',
#        'Inflow concentration of dissolved organic carbon (DOC) [mg m-3]',
#        'Inflow concentration of dissolved inorganic carbon (DIC) [mg m-3]',
#        'Inflow concentration of O2 [mg m-3]',
#        'Inflow concentration of NO3 [mg m-3]',
#        'Inflow concentration of NH4 [mg m-3]',
#        'Inflow concentration of SO4 [mg m-3]',
#        'Inflow concentration of aqueous iron (Fe2+) [mg m-3]',
#        'Inflow concentration of Ca2+ [mg m-3]', 'Inflow pH [-]',
#        'Inflow concentration of CH4 [mg m-3]',
#        'Inflow concentration of total solid iron (Fe3+) [mg m-3]',
#        'Inflow concentration of aluminum (Al3+) [mg m-3]',
#        'Inflow concentration of dissolved silica [mg m-3]',
#        '*Iron, suspended sediment, recoverable [mg m-3]',
#        '*Iron, water, unfiltered, recoverable [mg m-3]',
#        '*Iron, water, filtered [mg m-3]',
#        '*Suspended solids, water, unfiltered [mg m-3]'],
#       dtype='object')

# %%
Huron_river = pd.read_csv('/Users/imarkelo/git/Great-Lakes-Data/measurements/Excel Files/task 3/Western Basin/huronriver_average.csv', encoding='windows-1251')
Huron_river['Year'] = pd.to_numeric(Huron_river['Year'], errors='coerce')
Huron_river['Month'] = pd.to_numeric(Huron_river['Month'], errors='coerce')
Huron_river['Day'] = pd.to_numeric(Huron_river['Day'], errors='coerce')
Huron_river['Inflow volume [m3 d-1]'] = pd.to_numeric(Huron_river['Inflow volume [m3 d-1]'], errors='coerce')
Huron_river['*Orthophosphate, water, filtered, as PO4 [mg m-3]'] = pd.to_numeric(Huron_river['*Orthophosphate, water, filtered, as PO4 [mg m-3]'], errors='coerce')
Huron_river = Huron_river.dropna(subset=['Year', 'Month', 'Day', 'Inflow volume [m3 d-1]'])
Huron_river['Date'] = Huron_river.apply(lambda x:datetime.datetime.strptime("{0} {1} {2} 00:00:00".format(int(x['Year']),int(x['Month']), int(x['Day'])), "%Y %m %d %H:%M:%S"),axis=1)
Huron_river = Huron_river.groupby(['Date']).mean().reset_index()

Huron_river[['Date','Inflow volume [m3 d-1]']].to_csv('proc_data/Flow_Huron_River_USGS_data.csv', index=False)

Huron_river = Huron_river.dropna(subset=['*Orthophosphate, water, filtered, as PO4 [mg m-3]'])
Huron_river['*Orthophosphate, water, filtered, as PO4 [mg m-3]'] = Huron_river['*Orthophosphate, water, filtered, as PO4 [mg m-3]']/1000
Huron_river[['Date','Month','*Orthophosphate, water, filtered, as PO4 [mg m-3]']].to_csv('proc_data/SRP_Huron_River_USGS_data.csv', index=False)

# %%
Huron_river = pd.read_csv('/Users/imarkelo/git/Great-Lakes-Data/measurements/Excel Files/task 3/Western Basin/huronriver_average.csv', encoding='windows-1251')
Huron_river['Year'] = pd.to_numeric(Huron_river['Year'], errors='coerce')
Huron_river['Month'] = pd.to_numeric(Huron_river['Month'], errors='coerce')
Huron_river['Day'] = pd.to_numeric(Huron_river['Day'], errors='coerce')
Huron_river['Inflow volume [m3 d-1]'] = pd.to_numeric(Huron_river['Inflow volume [m3 d-1]'], errors='coerce')
Huron_river['Inflow concentration of dissolved silica [mg m-3]'] = pd.to_numeric(Huron_river['Inflow concentration of dissolved silica [mg m-3]'], errors='coerce')
Huron_river = Huron_river.dropna(subset=['Year', 'Month', 'Day', 'Inflow volume [m3 d-1]'])
Huron_river['Date'] = Huron_river.apply(lambda x:datetime.datetime.strptime("{0} {1} {2} 00:00:00".format(int(x['Year']),int(x['Month']), int(x['Day'])), "%Y %m %d %H:%M:%S"),axis=1)
Huron_river = Huron_river.groupby(['Date']).mean().reset_index()


Huron_river = Huron_river.dropna(subset=['Inflow concentration of dissolved silica [mg m-3]'])
Huron_river['Inflow concentration of dissolved silica [mg m-3]'] = Huron_river['Inflow concentration of dissolved silica [mg m-3]']/1000
Huron_river[['Date','Month','Inflow concentration of dissolved silica [mg m-3]']].to_csv('proc_data/Si_Huron_River_USGS_data.csv', index=False)

# %%
Cattaraugus_creek.columns
# Out:
# Index(['Year', 'Month', 'Day', ' Inflow volume [m3 d-1]',
#        ' Inflow temperature [°C]',
#        ' *Suspended sediment concentration [mg m-3]',
#        ' *Orthophosphate, water, filtered, as phosphorus [mg m-3]',
#        ' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]',
#        ' *Phosphorus, water, filtered, as phosphorus [mg m-3]',
#        ' *Orthophosphate, water, filtered, as PO4 [mg m-3]',
#        ' Inflow concentration of chlorophyll-a (Chla-P) [mg m-3]',
#        ' Inflow concentration of dissolved organic carbon (DOC) [mg m-3]',
#        'Inflow concentration of dissolved inorganic carbon (DIC) [mg m-3]',
#        ' Inflow concentration of O2 [mg m-3]',
#        ' Inflow concentration of NO3 [mg m-3]',
#        ' Inflow concentration of NH4 [mg m-3]',
#        ' Inflow concentration of SO4 [mg m-3]',
#        'Inflow concentration of aqueous iron (Fe2+) [mg m-3]',
#        ' Inflow concentration of Ca2+ [mg m-3]', ' Inflow pH [-]',
#        'Inflow concentration of CH4 [mg m-3]',
#        'Inflow concentration of total solid iron (Fe3+) [mg m-3]',
#        ' Inflow concentration of aluminum (Al3+) [mg m-3]',
#        ' Inflow concentration of dissolved silica [mg m-3]',
#        ' *Iron, suspended sediment, recoverable [mg m-3]',
#        ' *Iron, water, unfiltered, recoverable [mg m-3]',
#        ' *Iron, water, filtered [mg m-3]',
#        ' *Suspended solids, water, unfiltered [mg m-3]'],
#       dtype='object')

# %%
Cattaraugus_creek = pd.read_csv('/Users/imarkelo/git/Great-Lakes-Data/measurements/Excel Files/task 3/Eastern Basin/cattarauguscreek_average.csv', encoding='windows-1251')
Cattaraugus_creek['Year'] = pd.to_numeric(Cattaraugus_creek['Year'], errors='coerce')
Cattaraugus_creek['Month'] = pd.to_numeric(Cattaraugus_creek['Month'], errors='coerce')
Cattaraugus_creek['Day'] = pd.to_numeric(Cattaraugus_creek['Day'], errors='coerce')
Cattaraugus_creek[' Inflow volume [m3 d-1]'] = pd.to_numeric(Cattaraugus_creek[' Inflow volume [m3 d-1]'], errors='coerce')
Cattaraugus_creek[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'] = pd.to_numeric(Cattaraugus_creek[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'], errors='coerce')
Cattaraugus_creek = Cattaraugus_creek.dropna(subset=['Year', 'Month', 'Day', ' Inflow volume [m3 d-1]'])
Cattaraugus_creek['Date'] = Cattaraugus_creek.apply(lambda x:datetime.datetime.strptime("{0} {1} {2} 00:00:00".format(int(x['Year']),int(x['Month']), int(x['Day'])), "%Y %m %d %H:%M:%S"),axis=1)
Cattaraugus_creek = Cattaraugus_creek.groupby(['Date']).mean().reset_index()

Cattaraugus_creek[['Date',' Inflow volume [m3 d-1]']].to_csv('proc_data/Flow_Cattaraugus_creek_USGS_data.csv', index=False)

Cattaraugus_creek = pd.read_csv('/Users/imarkelo/git/Great-Lakes-Data/measurements/Excel Files/task 3/Eastern Basin/cattarauguscreek_average.csv', encoding='windows-1251')
Cattaraugus_creek['Year'] = pd.to_numeric(Cattaraugus_creek['Year'], errors='coerce')
Cattaraugus_creek['Month'] = pd.to_numeric(Cattaraugus_creek['Month'], errors='coerce')
Cattaraugus_creek['Day'] = pd.to_numeric(Cattaraugus_creek['Day'], errors='coerce')
Cattaraugus_creek[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'] = pd.to_numeric(Cattaraugus_creek[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'], errors='coerce')
Cattaraugus_creek = Cattaraugus_creek.dropna(subset=['Year', 'Month', 'Day',' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'])
Cattaraugus_creek['Date'] = Cattaraugus_creek.apply(lambda x:datetime.datetime.strptime("{0} {1} {2} 00:00:00".format(int(x['Year']),int(x['Month']), int(x['Day'])), "%Y %m %d %H:%M:%S"),axis=1)
Cattaraugus_creek[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]'] = Cattaraugus_creek[' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]']/1000
Cattaraugus_creek[['Date','Month',' *Phosphorus, water, unfiltered, as phosphorus [mg m-3]']].to_csv('proc_data/TP_Cattaraugus_creek_USGS_data.csv', index=False)

# %%
Cattaraugus_creek.describe()
# Out:
#               Year       Month         Day   Inflow volume [m3 d-1]  \
# count   207.000000  207.000000  207.000000             2.070000e+02
# mean   2000.212560    6.333333   14.748792             2.898243e+06
# std      13.057871    3.279830    9.360353             4.849105e+06
# min    1980.000000    1.000000    1.000000             1.957260e+05
# 25%    1988.000000    4.000000    6.000000             6.422261e+05
# 50%    1997.000000    6.000000   13.000000             1.304025e+06
# 75%    2013.000000    9.000000   23.000000             2.495507e+06
# max    2017.000000   12.000000   31.000000             3.816658e+07
#
#         Inflow temperature [°C]   *Suspended sediment concentration [mg m-3]  \
# count                205.000000                                 1.900000e+02
# mean                  11.005935                                 2.641368e+05
# std                    8.193004                                 8.068167e+05
# min                   -0.050000                                 4.000000e+03
# 25%                    3.300000                                 1.700000e+04
# 50%                    9.500000                                 3.150000e+04
# 75%                   18.800000                                 1.385000e+05
# max                   27.200000                                 8.170000e+06
#
#         *Phosphorus, water, unfiltered, as phosphorus [mg m-3]  \
# count                                         207.000000
# mean                                            0.164517
# std                                             0.393510
# min                                             0.006000
# 25%                                             0.012000
# 50%                                             0.030000
# 75%                                             0.104500
# max                                             3.660000
#
#         *Phosphorus, water, filtered, as phosphorus [mg m-3]  \
# count                                          88.000000
# mean                                           12.500000
# std                                             8.610339
# min                                            10.000000
# 25%                                            10.000000
# 50%                                            10.000000
# 75%                                            10.000000
# max                                            70.000000
#
#         *Orthophosphate, water, filtered, as PO4 [mg m-3]  \
# count                                         171.000000
# mean                                           23.526316
# std                                            14.846000
# min                                            12.000000
# 25%                                            12.000000
# 50%                                            21.000000
# 75%                                            31.000000
# max                                           153.000000
#
#         Inflow concentration of chlorophyll-a (Chla-P) [mg m-3]  \
# count                                           6.000000
# mean                                            1.016667
# std                                             0.640052
# min                                             0.400000
# 25%                                             0.625000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             2.200000
#
#                 ...             Inflow concentration of Ca2+ [mg m-3]  \
# count           ...                                        143.000000
# mean            ...                                      45913.636364
# std             ...                                       9555.216078
# min             ...                                      20200.000000
# 25%             ...                                      41300.000000
# 50%             ...                                      47000.000000
# 75%             ...                                      52800.000000
# max             ...                                      68000.000000
#
#         Inflow pH [-]  Inflow concentration of CH4 [mg m-3]  \
# count      202.000000                                   0.0
# mean         8.143977                                   NaN
# std          0.284053                                   NaN
# min          7.200000                                   NaN
# 25%          8.000000                                   NaN
# 50%          8.200000                                   NaN
# 75%          8.350000                                   NaN
# max          8.750000                                   NaN
#
#        Inflow concentration of total solid iron (Fe3+) [mg m-3]  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#         Inflow concentration of aluminum (Al3+) [mg m-3]  \
# count                                          47.000000
# mean                                           24.255319
# std                                            21.238263
# min                                            10.000000
# 25%                                            10.000000
# 50%                                            20.000000
# 75%                                            30.000000
# max                                           130.000000
#
#         Inflow concentration of dissolved silica [mg m-3]  \
# count                                          90.000000
# mean                                         3742.444444
# std                                          1016.629495
# min                                           820.000000
# 25%                                          2932.500000
# 50%                                          3800.000000
# 75%                                          4490.000000
# max                                          5800.000000
#
#         *Iron, suspended sediment, recoverable [mg m-3]  \
# count                                         11.000000
# mean                                        2325.454545
# std                                         1647.491206
# min                                          430.000000
# 25%                                         1200.000000
# 50%                                         1900.000000
# 75%                                         2750.000000
# max                                         5700.000000
#
#         *Iron, water, unfiltered, recoverable [mg m-3]  \
# count                                        35.000000
# mean                                       3004.571429
# std                                        5999.861931
# min                                         250.000000
# 25%                                         535.000000
# 50%                                        1200.000000
# 75%                                        2750.000000
# max                                       34000.000000
#
#         *Suspended solids, water, unfiltered [mg m-3]  Inflow volume [m3 d-1]
# count                                        3.000000              207.000000
# mean                                        10.666667               14.748792
# std                                          5.033223                9.360353
# min                                          6.000000                1.000000
# 25%                                          8.000000                6.000000
# 50%                                         10.000000               13.000000
# 75%                                         13.000000               23.000000
# max                                         16.000000               31.000000
#
# [8 rows x 27 columns]

# %%
csvfiles = []
for file in glob.glob("../../measurements/ncwqr.org/*.xlsx"):
    print(file)
    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Datetime (date and time of sample collection)']).apply(datetime.datetime.date)
    df['Flow, CFS'] = pd.to_numeric(df['Flow, CFS'], errors='coerce')
    df = df[df['Flow, CFS'] >=0]
    df = df.groupby(['Date']).mean().reset_index()
    df[['Date','Flow, CFS']].to_csv('proc_data/Flow_'+file.split("/")[-1].split('.')[0]+'.csv', index=False)

    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Datetime (date and time of sample collection)']).apply(datetime.datetime.date)
    df['TP, mg/L as P'] = pd.to_numeric(df['TP, mg/L as P'], errors='coerce')
    df = df[df['TP, mg/L as P'] >=0]
    df = df.dropna(subset=['TP, mg/L as P'])
    df = df.groupby(['Date']).mean().reset_index()
    df['code'] = 0
    df[['Date','code','TP, mg/L as P']].to_csv('proc_data/TP_'+file.split("/")[-1].split('.')[0]+'.csv', index=False)
    
    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Datetime (date and time of sample collection)']).apply(datetime.datetime.date)
    df['SRP, mg/L, as P'] = pd.to_numeric(df['SRP, mg/L, as P'], errors='coerce')
    df = df[df['SRP, mg/L, as P'] >=0]
    df = df.dropna(subset=['SRP, mg/L, as P'])
    df = df.groupby(['Date']).mean().reset_index()
    df['code'] = 0
    df[['Date','code','SRP, mg/L, as P']].to_csv('proc_data/SRP_'+file.split("/")[-1].split('.')[0]+'.csv', index=False)
    
    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Datetime (date and time of sample collection)']).apply(datetime.datetime.date)
    df['Chloride, mg/L'] = pd.to_numeric(df['Chloride, mg/L'], errors='coerce')
    df = df[df['Chloride, mg/L'] >=0]
    df = df.dropna(subset=['Chloride, mg/L'])
    df = df.groupby(['Date']).mean().reset_index()
    df['code'] = 0
    df[['Date','code','Chloride, mg/L']].to_csv('proc_data/Cl_'+file.split("/")[-1].split('.')[0]+'.csv', index=False)
    
    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Datetime (date and time of sample collection)']).apply(datetime.datetime.date)
    df['NO23, mg/L as N'] = pd.to_numeric(df['NO23, mg/L as N'], errors='coerce')
    df = df[df['NO23, mg/L as N'] >=0]
    df = df.dropna(subset=['NO23, mg/L as N'])
    df = df.groupby(['Date']).mean().reset_index()
    df['code'] = 0
    df[['Date','code','NO23, mg/L as N']].to_csv('proc_data/NO32_'+file.split("/")[-1].split('.')[0]+'.csv', index=False)

    df = pd.read_excel(file)
    df['Date'] = pd.to_datetime(df['Datetime (date and time of sample collection)']).apply(datetime.datetime.date)
    df['Silica, mg/L'] = pd.to_numeric(df['Silica, mg/L'], errors='coerce')
    df = df[df['Silica, mg/L'] >=0]
    df = df.dropna(subset=['Silica, mg/L'])
    df = df.groupby(['Date']).mean().reset_index()
    df['code'] = 0
    df[['Date','code','Silica, mg/L']].to_csv('proc_data/Si_'+file.split("/")[-1].split('.')[0]+'.csv', index=False)
# Out:
# ../../measurements/ncwqr.org/Huron_River_data.xlsx
# ../../measurements/ncwqr.org/Grand_River_US_data.xlsx
