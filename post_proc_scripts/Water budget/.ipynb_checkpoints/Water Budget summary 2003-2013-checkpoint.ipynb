# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

sns.set_style("whitegrid")
sns.set_style("ticks")
from datetime import datetime
str(datetime.now())

import scipy as sp

# %%
table = pd.read_excel('/Users/imarkelo/Google Drive/GDocuments/Lake Erie/Draft/Water Budget/Water Budget_gauged.xlsx', sheet_name='Total Annual 0.75')

# %%
table
# Out:
#                             cms         2003         2004         2005  \
# Inflow          St. Clair River  4782.000729  5060.392060  5002.331177
# St Clair Basin        US Rivers    21.751691    35.038728    29.287122
# NaN                   CA Rivers    98.036614   122.508836   131.862506
# NaN               Precipitation    20.607375    20.491887    18.612589
# NaN                 Evaporation    26.893407    29.691378    29.487300
# NaN                         NBS   113.502273   148.348074   150.274917
# Channel           Detroit River  4861.041064  5188.579370  5123.287386
# Western Basin         US Rivers   347.860308   280.616523   308.705564
# NaN                   CA Rivers     1.871766     3.136817     2.573567
# NaN               Precipitation    52.572855    52.278226    47.483822
# NaN                 Evaporation    68.609571    75.747662    75.227026
# NaN                         NBS   333.695357   260.283904   283.535927
# Central Basin         US Rivers   260.840775   264.605530   274.682860
# NaN                   CA Rivers    14.382040    16.330120    16.184974
# NaN               Precipitation   295.828673   294.170793   267.192567
# NaN                 Evaporation   386.067651   426.233852   423.304224
# NaN                         NBS   184.983836   148.872591   134.756177
# Eastern Basin         US Rivers    58.005961    66.162904    55.109462
# NaN                   CA Rivers    84.094580    98.666836    92.400178
# NaN               Precipitation   127.824921   127.108565   115.451516
# NaN                 Evaporation   166.816375   184.171831   182.905965
# NaN                         NBS   103.109087   107.766474    80.055191
# Outflow           Niagara River  5326.794521  5674.535515  5750.958904
# Risidual                    NaN   190.496763    51.127588  -100.005516
#
#                        2006         2007         2008         2009  \
# Inflow          4968.235953  4804.197425  4859.677194  5218.747463
# St Clair Basin    41.395654    28.305725    40.328556    54.422797
# NaN              179.691400    94.698968   197.150347   159.924658
# NaN               24.815254    21.205776    24.195075    22.879107
# NaN               31.254595    33.303075    33.542524    30.584486
# NaN              214.647713   110.907394   228.131453   206.642076
# Channel         5093.068461  4909.041064  5043.551909  5487.020041
# Western Basin    358.290039   384.247717   391.032259   305.688821
# NaN                3.200575     2.548749     3.987866     2.722265
# NaN               63.307857    54.099474    61.725676    58.368422
# NaN               79.735691    84.961705    85.572578    78.026130
# NaN              345.062780   355.934234   371.173223   288.753378
# Central Basin    268.554245   268.183409   301.613606   157.569846
# NaN               22.508287    12.380475    23.530653    19.306063
# NaN              356.234782   304.418998   347.331813   328.440467
# NaN              448.674587   478.081489   481.518885   439.054843
# NaN              198.622727   106.901394   190.957186    66.261533
# Eastern Basin     62.951759    51.095003    51.675884    51.844072
# NaN              124.512938    67.384872   145.056951   106.722265
# NaN              153.925859   131.536723   150.078966   141.916185
# NaN              193.868271   206.574730   208.059999   189.711666
# NaN              147.522284    43.441868   138.751801   110.770856
# Western Basin    327.169928
# NaN                2.833150
# NaN               73.830834
# NaN               81.184940
# NaN              322.648972
# Central Basin    243.328511
# NaN               17.261833
# NaN              415.447815
# NaN              456.829543
# NaN              219.208615
# Eastern Basin     52.868727
# NaN              102.020945
# NaN              179.511281
# NaN              197.391955
# NaN              137.008998
# Outflow         5859.973882
# Risidual          86.389784

# %%
st_clair = table.iloc[0][1:-1]/table.iloc[0][-1]*100 - 100

# %%
st_clair
# Out:
# 2003   -6.15303
# 2004   -0.68959
# 2005   -1.82904
# 2006   -2.49816
# 2007   -5.71742
# 2008   -4.62863
# 2009    2.41814
# 2010   -1.67697
# 2011   -7.47319
# 2012   -4.44528
# 2013   -5.71951
# 2014    1.44676
# 2015    6.67382
# 2016    15.3283
# 2017    14.9638
# Name: Inflow, dtype: object

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(st_clair.index.values, st_clair.values, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/clair_river.pdf')

# %%
f, axes = plt.subplots(2,2, figsize=(1*2,0.65*2), dpi=600, sharex=True, sharey=True)

labels = ['US', 'CA', 'P', 'E']
colors = [0,3,1,2]

for i,ax1 in enumerate(axes):
    for j, ax in enumerate(ax1):
        ax.axhline(0, c='k', ls='--', lw=0.3)
        ax.plot(table.iloc[(i+1)*i+j+1][1:-1]/table.iloc[(i+1)*i+j+1][-1]*100 - 100, lw=1, label='St.Clair', c=sns.color_palette()[colors[(i+1)*i+j]])
        ax.set_xlabel('')
        # axes.grid(lw=0.2)
        # axes.set_ylim(-15,15)
        # axes.set_xlim(3,17)
        # axes.set_ylabel('%')
        ax.yaxis.set_tick_params(width=0.3)
        for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(0.3)
        ax.text(0.5,1.1, labels[(i+1)*i+j], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.set_xlabel('')
        # plt.xticks(rotation='45')
        # axes.legend(loc=2, frameon=1, framealpha=1)
        # axes.get_xaxis().set_ticklabels([])
        ax.get_xaxis().set_ticks([])

plt.subplots_adjust(hspace=.6, wspace=.6)
sns.despine(offset=1, trim=True,bottom=True);
# plt.tight_layout()
f.savefig('img/clair_lake.pdf')
