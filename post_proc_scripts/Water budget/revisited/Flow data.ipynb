# %%
import hydrofunctions as hf
import pandas as pd
import numpy as np
from zipfile import ZipFile
import os
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("ticks")

import matplotlib.pyplot as plt
import numpy as np

from matplotlib import rc
import matplotlib.ticker as tkr
import matplotlib.dates as mdates
from datetime import datetime, timedelta
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("whitegrid")
sns.set_style("ticks")
import scipy.io as sio
import cmocean

import sys
sys.path.append('../../')


import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline


sns.set_style("whitegrid")
sns.set_style("ticks")

rc('text', usetex=False)
rc("savefig", dpi=90)
rc("figure", dpi=90)

plt.rcParams['figure.figsize'] = 6, 4

import pandas as pd

pd.options.display.max_columns = 999
pd.options.display.max_rows = 400

import h5py

from datetime import datetime
str(datetime.now())
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/cmocean/tools.py:76: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not mpl.cbook.is_string_like(rgbin[0]):
# '2019-09-23 10:58:29.906681'

# %%
import pickle

# %%
fname = '../../Loadings Canada 2/data/all_flows.pkl'

with open(fname, 'rb') as f:  # with statement avoids file leak
    all_flows = pickle.load(f, encoding='latin-1')

# %%
all_flows.head()
# Out:
#             02FD002  02FE002  02FE003  02FE005  02FE007  02FE008  02FE009  \
# 1996-01-01     1.04     10.5    0.283     3.43     2.19     2.67     1.47
# 1996-01-02     1.05     10.4    0.267     3.41     2.16     2.60     1.46
# 1996-01-03     1.04     10.2    0.267     3.40     2.13     2.55     1.45
# 1996-01-04     1.03     10.0    0.236     3.39     2.10     2.50     1.43
# 1996-01-05     1.02      9.9    0.217     3.38     2.08     2.45     1.42
#
#             02FE010  02FE011  02FE013  02FE014  02FE015  02FE016  02FE017  \
# 1996-01-01      NaN    0.403     1.18      NaN     12.9      NaN      NaN
# 1996-01-02      NaN    0.397     1.15      NaN     12.8      NaN      NaN
# 1996-01-03      NaN    0.388     1.13      NaN     12.7      NaN      NaN
# 1996-01-04      NaN    0.378     1.08      NaN     12.6      NaN      NaN
# 1996-01-05      NaN    0.372     1.05      NaN     12.5      NaN      NaN
#
# ...

# %%
fname = '/Users/imarkelo/git/Great-Lakes-Data/measurements/LE pickles/master_df'
with open(fname, 'rb') as f:  # with statement avoids file leak
    master_df = pickle.load(f, encoding='latin-1')

# %%
master_df
# Out:
#    basin country                                       STATION_NAME  \
# 0    SCR      US                  St. Clair River At Port Huron, MI
# 1    SCR      US                         Black River Near Fargo, MI
# 2    SCR      US                         Black River Near Jeddo, MI
# 3    SCR      US                          Mill Creek Near Avoca, MI
# 4    SCR      US                         Belle River At Memphis, MI
# 5    SCR      CA                  St. Clair River At Port Huron, ON
# 6    SCL      US  Clinton River At Moravian Drive At Mt. Clemens...
# 7    SCL      US    North Branch Clinton River Near Mt. Clemens, MI
# 8    SCL      CA                    Thames River At Thamesville, ON
# 9    SCL      CA                       Thames River Near Dutton, ON
# 10   SCL      CA                          Thames River At Byron, ON
# 11   SCL      CA                     Sydenham River At Florence, ON
# 12   SCL      CA                  Sydenham River Near Alvinston, ON
# ...

# %%
DR = master_df[(master_df.basin=='DR')].STATION_NUMBER.values[1:]
DR
# Out:
# array(['04166500', '04167000', '04168400', '04168580', '02GH003',
#        '02GH011', '02GH004', '02GH016'], dtype=object)

# %%
WB = master_df[(master_df.basin=='WB')].STATION_NUMBER.values
WB
# Out:
# array(['04193500', '04176500', '04174500', '04195820', '04177000',
#        '04168000', '04176605', '04193999', '04174518'], dtype=object)

# %%
SCR_r = master_df[1:5].STATION_NUMBER.values

# %%
SCR = master_df[5:6].STATION_NUMBER.values

# %%
all_flows['year'] = all_flows.index.year
all_flows['month'] = all_flows.index.month

# %%
DR_r =  master_df[19:20].STATION_NUMBER.values
DR_r
# Out:
# array(['04165710'], dtype=object)

# %%
all_flows = all_flows.fillna(all_flows.mean())

# %%
agg_flows = all_flows.groupby(['year', 'month']).mean().reset_index()
# WB/0.85

# %%
agg_flows[(agg_flows.year > 2003)&(agg_flows.month>3)&(agg_flows.month<7)].groupby('year').mean()[DR_r]
# Out:
#          04165710
# year
# 2004  5833.311778
# 2005  5833.311778
# 2006  5833.311778
# 2007  5833.311778
# 2008  5833.311778
# 2009  5833.311778
# 2010  5833.311778
# 2011  5833.311778
# 2012  5833.311778
# 2013  5833.311778
# 2014  5796.810470
# 2015  5968.961252
# 2016  6711.258781
# 2017  6615.025090

# %%
agg_flows.index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-69e6366b77a6> in <module>
# ----> 1 agg_flows.index(0)
#
# TypeError: 'MultiIndex' object is not callable
