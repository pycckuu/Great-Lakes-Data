# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

sns.set_style("whitegrid")
sns.set_style("ticks")
from datetime import datetime
str(datetime.now())

import scipy as sp

# %%
table = pd.read_excel('/Users/imarkelo/Google Drive/GDocuments/Lake Erie/Draft/Water Budget/Water Budget_gauged.xlsx', sheet_name='Total Annual re-estem')

# %%
table
# Out:
#                   RWB             HC          2003          2004  \
# 0     St. Clair River     Outflow LH  4.845006e+03  4.990752e+03
# 1                 NaN      US Runoff  3.740489e+00  1.046428e+01
# 2                 NaN      CA Runoff  6.340130e-01  1.773696e+00
# 3                 NaN        Outflow  4.849381e+03  5.002990e+03
# 4      St Clair Basin      US Runoff  1.906283e+01  3.344134e+01
# 5                 NaN      CA Runoff  6.517928e+01  1.341936e+02
# 6                 NaN  Precipitation  2.140406e+01  3.161243e+01
# 7                 NaN    Evaporation  2.701139e+01  3.126095e+01
# 8                 NaN        Outflow  4.928016e+03  5.170976e+03
# 9       Detroit River      US Runoff  1.070879e+01  1.593182e+01
# 10                NaN      CA Runoff  2.750793e+00  5.744500e+00
# 11                NaN        Outflow  4.941475e+03  5.192652e+03
# 12      Western Basin      US Runoff  2.526540e+02  2.559592e+02
# ...

# %%
table.T[0][2:-1]
# Out:
# 2003    4845.01
# 2004    4990.75
# 2005    5059.18
# 2006    4988.61
# 2007    4824.88
# 2008    4794.03
# 2009    5125.28
# 2010    5083.46
# 2011    4751.31
# 2012    4909.93
# 2013    4739.23
# 2014     4971.1
# 2015    5436.31
# 2016    5856.36
# 2017    5846.76
# Name: 0, dtype: object

# %%
st_clair = table.iloc[0][1:-1]/table.iloc[0][-1]*100 - 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
st_clair = table.T[0][2:-1]/table.T[0][-1]*100 - 100

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(st_clair.index.values, st_clair.values, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
# axes.text(1.2,0.35, str(table.iloc[0][-1]).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=axes.transAxes)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
axes.get_xaxis().set_ticklabels([])
# for label in (axes.get_xticklabels() + axes.get_yticklabels()):
#     label.set_fontname('Arial')
#     label.set_fontsize(5)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/clair_river.pdf')

# %%
table.iloc[12][2:-1]
# Out:
# 2003    252.654
# 2004    255.959
# 2005    277.997
# 2006    258.591
# 2007    357.992
# 2008    391.269
# 2009    271.171
# 2010    230.572
# 2011    319.636
# 2012    298.245
# 2013    241.195
# 2014    279.968
# 2015    304.847
# 2016    195.197
# 2017    323.615
# Name: 12, dtype: object

# %%
table
# Out:
#                   RWB             HC          2003          2004  \
# 0     St. Clair River     Outflow LH  4.845006e+03  4.990752e+03
# 1                 NaN      US Runoff  3.740489e+00  1.046428e+01
# 2                 NaN      CA Runoff  6.340130e-01  1.773696e+00
# 3                 NaN        Outflow  4.849381e+03  5.002990e+03
# 4      St Clair Basin      US Runoff  1.906283e+01  3.344134e+01
# 5                 NaN      CA Runoff  6.517928e+01  1.341936e+02
# 6                 NaN  Precipitation  2.140406e+01  3.161243e+01
# 7                 NaN    Evaporation  2.701139e+01  3.126095e+01
# 8                 NaN        Outflow  4.928016e+03  5.170976e+03
# 9       Detroit River      US Runoff  1.070879e+01  1.593182e+01
# 10                NaN      CA Runoff  2.750793e+00  5.744500e+00
# 11                NaN        Outflow  4.941475e+03  5.192652e+03
# 12      Western Basin      US Runoff  2.526540e+02  2.559592e+02
# ...

# %%
(table.iloc[idx][2:-1] )/\
                (table.iloc[idx][-1] )*100 - 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-8acffe16766c> in <module>
#       1 (table.iloc[idx][2:-1] )/\
# ----> 2                 (table.iloc[idx][-1] )*100 - 100
#
# NameError: name 'idx' is not defined

# %%
f, axes = plt.subplots(2,2, figsize=(1*2,1*2), dpi=600, sharex=True, sharey=True)

labels = ['US$^\star$', 'CA$^\star$', 'P', 'E']
colors = [0,3,1,2]
strartin_idx = 4

data = [
    ((table.iloc[4][2:-1]+table.iloc[1][2:-1])/(table.iloc[4][-1]+table.iloc[1][-1])*100 - 100, table.iloc[4][-1]+table.iloc[1][-1]),
    ((table.iloc[5][2:-1]+table.iloc[2][2:-1])/(table.iloc[5][-1]+table.iloc[2][-1])*100 - 100, table.iloc[5][-1]+table.iloc[2][-1]),
    (table.iloc[6][2:-1]/table.iloc[6][-1]*100 - 100, table.iloc[6][-1]),
    (table.iloc[7][2:-1]/table.iloc[7][-1]*100 - 100, table.iloc[7][-1]),
]


for i,ax1 in enumerate(axes):
    for j, ax in enumerate(ax1):
        ax.axhline(0, c='k', ls='--', lw=0.3)
        ax.plot(data[(i+1)*i+j][0], lw=1, label='St.Clair', c='k')#c=sns.color_palette()[colors[(i+1)*i+j]])
        ax.set_xlabel('')
        # axes.grid(lw=0.2)
        # axes.set_ylim(-15,15)
        # axes.set_xlim(3,17)
        # axes.set_ylabel('%')
        ax.yaxis.set_tick_params(width=0.3)
        for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(0.3)
        ax.text(0.5,1.1, labels[(i+1)*i+j], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.text(1.2,0.4, str(round(data[(i+1)*i+j][1])).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, weight='bold')
        ax.set_xlabel('')
        # plt.xticks(rotation='45')
        # axes.legend(loc=2, frameon=1, framealpha=1)
        ax.get_xaxis().set_ticks([])
        ax.set_ylim(-50,70)
        ax.get_yaxis().set_ticks([0,50])
        ax.get_yaxis().set_ticklabels(['0', '50%'])

plt.subplots_adjust(hspace=.7, wspace=.9, left=0.2, right=0.88)
sns.despine(offset=1, trim=True,bottom=True);
# plt.tight_layout()
f.savefig('img/clair_lake.pdf')

# %%
table.iloc[8]
# Out:
# RWB         NaN
# HC      Outflow
# 2003    4928.02
# 2004    5170.98
# 2005       5209
# 2006     5161.7
# 2007    5016.57
# 2008    4984.49
# 2009    5426.38
# 2010    5190.81
# 2011     4991.7
# 2012    5056.07
# 2013    4922.67
# 2014    5184.48
# 2015    5575.37
# 2016    5998.11
# 2017    6028.69
# Mean    5256.33
# Name: 8, dtype: object

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(table.iloc[8][2:-1]/table.iloc[8][-1]*100 - 100, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/detroit_river.pdf')

# %%
f, axes = plt.subplots(2,2, figsize=(1*2,1*2), dpi=600, sharex=True, sharey=True)

labels = ['US$^\star$', 'CA$^\star$', 'P', 'E']
colors = [0,3,1,2]

data = [
    ((table.iloc[9][2:-1]+table.iloc[12][2:-1])/(table.iloc[9][-1]+table.iloc[12][-1])*100 - 100, table.iloc[9][-1]+table.iloc[12][-1]),
    ((table.iloc[10][2:-1]+table.iloc[13][2:-1])/(table.iloc[10][-1]+table.iloc[13][-1])*100 - 100, table.iloc[10][-1]+table.iloc[13][-1]),
    (table.iloc[14][2:-1]/table.iloc[14][-1]*100 - 100, table.iloc[14][-1]),
    (table.iloc[15][2:-1]/table.iloc[15][-1]*100 - 100, table.iloc[15][-1]),
]


for i,ax1 in enumerate(axes):
    for j, ax in enumerate(ax1):
        ax.axhline(0, c='k', ls='--', lw=0.3)
        ax.plot(data[(i+1)*i+j][0], lw=1, label='St.Clair', c='k')#c=sns.color_palette()[colors[(i+1)*i+j]])
        ax.set_xlabel('')
        # axes.grid(lw=0.2)
        # axes.set_ylim(-15,15)
        # axes.set_xlim(3,17)
        # axes.set_ylabel('%')
        ax.yaxis.set_tick_params(width=0.3)
        for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(0.3)
        ax.text(0.5,1.1, labels[(i+1)*i+j], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.text(1.25,0.4, str(round(data[(i+1)*i+j][1])).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, weight='bold')
        ax.set_xlabel('')
        # plt.xticks(rotation='45')
        # axes.legend(loc=2, frameon=1, framealpha=1)
        ax.get_xaxis().set_ticks([])
        ax.set_ylim(-50,70)
        ax.get_yaxis().set_ticks([0,50])
        ax.get_yaxis().set_ticklabels(['0', '50%'])

plt.subplots_adjust(hspace=.7, wspace=.9, left=0.2, right=0.88)
sns.despine(offset=1, trim=True,bottom=True);
# plt.tight_layout()
# f.savefig('img/clair_lake.pdf')


f.savefig('img/western.pdf')

# %%
table.iloc[16]
# Out:
# RWB         NaN
# HC      Outflow
# 2003    5190.81
# 2004    5448.97
# 2005    5498.73
# 2006    5447.38
# 2007    5403.66
# 2008    5412.55
# 2009    5743.13
# 2010    5433.14
# 2011    5367.98
# 2012    5369.19
# 2013    5193.69
# 2014    5506.35
# 2015    5900.38
# 2016    6199.63
# 2017    6392.01
# Mean    5567.17
# Name: 16, dtype: object

# %%
w_to_c = table.iloc[16]

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(w_to_c[2:-1]/w_to_c[-1]*100 - 100, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/w_to_c.pdf')

# %%
f, axes = plt.subplots(2,2, figsize=(1*2,1*2), dpi=600, sharex=True, sharey=True)

labels = ['US', 'CA', 'P', 'E']
colors = [0,3,1,2]
strartin_idx = 17
for i,ax1 in enumerate(axes):
    for j, ax in enumerate(ax1):
        ax.axhline(0, c='k', ls='--', lw=0.3)
        ax.plot(table.iloc[(i+1)*i+j+strartin_idx][2:-1]/table.iloc[(i+1)*i+j+strartin_idx][-1]*100 - 100, lw=1, label='St.Clair', c='k')#c=sns.color_palette()[colors[(i+1)*i+j]])
        ax.set_xlabel('')
        # axes.grid(lw=0.2)
        # axes.set_ylim(-15,15)
        # axes.set_xlim(3,17)
        # axes.set_ylabel('%')
        ax.yaxis.set_tick_params(width=0.3)
        for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(0.3)
        ax.text(0.5,1.1, labels[(i+1)*i+j], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.text(1.25,0.5, str(round(table.iloc[(i+1)*i+j+strartin_idx][-1])).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, weight='bold')
        ax.set_xlabel('')
        # plt.xticks(rotation='45')
        # axes.legend(loc=2, frameon=1, framealpha=1)
        # axes.get_xaxis().set_ticklabels([])
        ax.get_xaxis().set_ticks([])
        ax.set_ylim(-50,50)
        ax.get_yaxis().set_ticks([0,50])
        ax.get_yaxis().set_ticklabels(['0', '50%'])

plt.subplots_adjust(hspace=.7, wspace=.9, left=0.2, right=0.88)
sns.despine(offset=1, trim=True,bottom=True);
# plt.tight_layout()
f.savefig('img/central.pdf')

# %%
c_to_e = table.iloc[21]

# %%
c_to_e
# Out:
# RWB         NaN
# HC      Outflow
# 2003    5397.13
# 2004    5762.02
# 2005    5748.34
# 2006    5711.46
# 2007    5737.39
# 2008    5816.96
# 2009    6135.63
# 2010    5591.87
# 2011    5904.91
# 2012    5624.56
# 2013    5542.52
# 2014    5928.64
# 2015    6127.48
# 2016     6306.7
# 2017    6744.74
# Mean    5872.02
# Name: 21, dtype: object

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(c_to_e[2:-1]/c_to_e[-1]*100 - 100, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/c_to_e.pdf')

# %%
f, axes = plt.subplots(2,2, figsize=(1*2,1*2), dpi=600, sharex=True, sharey=True)

labels = ['US', 'CA', 'P', 'E']
colors = [0,3,1,2]
strartin_idx = 22
for i,ax1 in enumerate(axes):
    for j, ax in enumerate(ax1):
        ax.axhline(0, c='k', ls='--', lw=0.3)
        ax.plot(table.iloc[(i+1)*i+j+strartin_idx][2:-1]/table.iloc[(i+1)*i+j+strartin_idx][-1]*100 - 100, lw=1, label='St.Clair', c='k')#c=sns.color_palette()[colors[(i+1)*i+j]])
        ax.set_xlabel('')
        # axes.grid(lw=0.2)
        # axes.set_ylim(-15,15)
        # axes.set_xlim(3,17)
        # axes.set_ylabel('%')
        ax.yaxis.set_tick_params(width=0.3)
        for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(0.3)
        ax.text(0.5,1.1, labels[(i+1)*i+j], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.text(1.25,0.48, str(round(table.iloc[(i+1)*i+j+strartin_idx][-1])).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, weight='bold')
        ax.set_xlabel('')
        # plt.xticks(rotation='45')
        # axes.legend(loc=2, frameon=1, framealpha=1)
        # axes.get_xaxis().set_ticklabels([])
        ax.get_xaxis().set_ticks([])
        ax.set_ylim(-50,50)
        ax.get_yaxis().set_ticks([0,50])
        ax.get_yaxis().set_ticklabels(['0', '50%'])

plt.subplots_adjust(hspace=.7, wspace=.9, left=0.2, right=0.88)
sns.despine(offset=1, trim=True,bottom=True);
# plt.tight_layout()
f.savefig('img/eastern.pdf')

# %%
table.iloc[30]
# Out:
# RWB         NaN
# HC        Total
# 2003     5561.5
# 2004    5882.03
# 2005    6116.85
# 2006    5821.88
# 2007    6028.31
# 2008    5952.91
# 2009    6137.44
# 2010    5920.92
# 2011    5938.16
# 2012    6267.23
# 2013    5711.05
# 2014    6071.33
# 2015    6446.14
# 2016    6682.56
# 2017    6912.54
# Mean    6096.72
# Name: 30, dtype: object

# %%
niagara = table.iloc[26]

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(niagara[2:-1]/niagara[-1]*100 - 100, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/niagara.pdf')

# %%
niagara[-1]
# Out:
# 6099.741616400999
