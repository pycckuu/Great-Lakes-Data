# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

sns.set_style("whitegrid")
sns.set_style("ticks")
from datetime import datetime
str(datetime.now())

import scipy as sp

# %%
table = pd.read_excel('/Users/imarkelo/Google Drive/GDocuments/Lake Erie/Draft/Water Budget/Water Budget_gauged.xlsx', sheet_name='Total Annual re-estem')

# %%
table
# Out:
#                   RWB             HC         2003         2004         2005  \
# 0     St. Clair River     Outflow LH  4782.000729  5060.392060  5002.331177
# 1                 NaN      US Runoff     5.074288    10.798981     8.777848
# 2                 NaN      CA Runoff     9.532302    10.260222    14.073604
# 3                 NaN        Outflow  4796.607319  5081.451263  5025.182629
# 4      St Clair Basin      US Runoff    23.640303    34.915225    30.159578
# 5                 NaN      CA Runoff    95.789271   113.133511   113.731062
# 6                 NaN  Precipitation    21.404058    31.612433    27.306645
# 7                 NaN    Evaporation    27.011391    31.260954    31.124247
# 8                 NaN        Outflow  4910.429560  5229.851478  5165.255667
# 9       Detroit River      US Runoff    10.955731    14.251575    13.025273
# 10                NaN      CA Runoff     2.329200     4.006997     3.415249
# 11                NaN        Outflow  4923.714491  5248.110050  5181.696189
# 12      Western Basin      US Runoff   329.089754   266.707045   296.701873
# 13                NaN      CA Runoff     0.000000     0.000000     0.000000
# 14                NaN  Precipitation    69.755888    77.926998    70.152412
# 15                NaN    Evaporation    68.910570    79.751913    79.403151
# 16                NaN        Outflow  5253.649563  5512.992180  5469.147323
# 17      Central Basin      US Runoff   249.505219   254.219068   264.578863
# 18                NaN      CA Runoff    18.426863    21.376552    21.983776
# 19                NaN  Precipitation   392.518001   438.497029   394.749254
# 20                NaN    Evaporation   387.761375   448.765865   446.803376
# 21                NaN        Outflow  5526.338271  5778.318964  5703.655840
# 22      Eastern Basin      US Runoff    54.895197    62.606905    52.559780
# 23                NaN      CA Runoff    84.520794    98.342573    93.741082
# 24                NaN  Precipitation   169.603513   189.470640   170.567618
# 25                NaN    Evaporation   167.548218   193.907712   193.059738
# 26                NaN        Outflow  5667.809557  5934.831370  5827.464582
# 27            Outflow  Niagara River  5292.348493  5640.632131  5719.088219
# 28                NaN  Welland Canal   199.643210   201.275130   212.984146
# 29                NaN    Consumptive   106.000000   106.000000   106.000000
# 30                NaN          Total  5597.991703  5947.907261  6038.072365
# 31  Risidual (In-Out)            NaN    69.817854   -13.075891  -210.607783
# 32   Change in WL, cm            NaN    -9.200000    15.200000     5.300000
#
#            2006         2007         2008         2009         2010  \
# 0   4968.235953  4804.197425  4859.677194  5218.747463  5010.079782
# 1     13.013017     6.986587    11.077486    14.459652     5.905182
# 2     17.294701     8.978344    21.695975    13.372261     7.996603
# 3   4998.543671  4820.162356  4892.450655  5246.579376  5023.981567
# 4     42.181184    30.126745    43.149995    58.179072    26.249068
# 5    162.460850    85.913533   173.931235   139.654647    77.014261
# 6     38.191072    27.276918    39.068239    52.675647    23.766048
# 7     31.343967    30.996019    30.536797    27.674436    32.145485
# 8   5210.032810  4932.483533  5118.063327  5469.414306  5118.865459
# 24   291.367723   199.788749   237.529059   204.843725   194.205708
# 25   195.382354   223.913274   207.065547   172.154008   191.961974
# 26  6545.968003  5362.389091  5910.932713  6224.134707  6247.180536
# 27  5921.828384  5670.267541  5590.290411  5858.205370  6137.913863
# 28   158.463645   204.037517   174.212903   206.609377   224.847907
# 29   106.000000   106.000000   106.000000   106.000000   106.000000
# 30  6186.292029  5980.305058  5870.503314  6170.814747  6468.761770
# 31   359.675974  -617.915967    40.429399    53.319960  -221.581234
# 32    18.400000   -11.200000    -6.800000    15.100000    10.800000
#
#            2016         2017          Mean
# 0   5876.587043  5858.016394  5.095530e+03
# 1      8.826216     8.745694  9.084659e+00
# 2     11.446788    12.508844  1.263530e+01
# 3   5896.860047  5879.270932  5.117250e+03
# 4     30.726252    39.195186  3.580336e+01
# 5    106.571480   124.945461  1.238079e+02
# 6     27.819715    35.487533  3.241655e+01
# 7     37.106233    31.352067  3.134880e+01
# 8   6024.871261  6047.547045  5.277929e+03
# 9     12.794971    14.943138  1.430740e+01
# 10     3.642475     4.569909  3.890663e+00
# 11  6041.308707  6067.060092  5.296127e+03
# 12   218.846299   368.699339  3.126530e+02
# 13     0.000000     0.000000  1.000000e-09
# 14    84.615301   102.992072  8.713279e+01
# 15    94.664195    79.984359  7.997602e+01
# 16  6250.106112  6458.767144  5.615937e+03
# 17   156.876911   235.167102  2.348571e+02
# 18    17.348759    21.136608  2.296725e+01
# 19   476.132265   579.538780  4.902982e+02
# 20   532.677622   450.073845  4.500269e+02
# 21  6367.786425  6844.535789  5.914033e+03
# 22    38.080851    65.760907  5.282610e+01
# 23    89.356260   118.634523  1.025788e+02
# 24   205.732488   250.413517  2.118535e+02
# 25   230.165231   194.472878  1.944526e+02
# 26  6470.790793  7084.871858  6.086838e+03
# 27  6364.726557  6832.589011  5.828533e+03
# 28   207.797478   138.776573  1.906834e+02
# 29   106.000000   106.000000  1.060000e+02
# 30  6678.524035  7077.365584  6.125216e+03
# 31  -207.733242     7.506274  1.720370e+02
# 32     9.100000    17.100000  1.010667e+01

# %%
table.T[0][2:-1]
# Out:
# 2003       4782
# 2004    5060.39
# 2005    5002.33
# 2006    4968.24
# 2007     4804.2
# 2008    4859.68
# 2009    5218.75
# 2010    5010.08
# 2011    4714.73
# 2012    4869.02
# 2013    4804.09
# 2014    5169.25
# 2015     5435.6
# 2016    5876.59
# 2017    5858.02
# Name: 0, dtype: object

# %%
st_clair = table.iloc[0][1:-1]/table.iloc[0][-1]*100 - 100

# %%
st_clair = table.T[0][2:-1]/table.T[0][-1]*100 - 100

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(st_clair.index.values, st_clair.values, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
# axes.text(1.2,0.35, str(table.iloc[0][-1]).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=axes.transAxes)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
axes.get_xaxis().set_ticklabels([])
# for label in (axes.get_xticklabels() + axes.get_yticklabels()):
#     label.set_fontname('Arial')
#     label.set_fontsize(5)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
# f.savefig('img/clair_river.pdf')

# %%
table.iloc[12][2:-1]
# Out:
# 2003     329.09
# 2004    266.707
# 2005    296.702
# 2006    343.819
# 2007    364.183
# 2008    377.557
# 2009    294.004
# 2010    230.147
# 2011    517.621
# 2012    168.588
# 2013    293.819
# 2014    283.638
# 2015    336.375
# 2016    218.846
# 2017    368.699
# Name: 12, dtype: object

# %%
table
# Out:
#                   RWB             HC          2003          2004  \
# 0     St. Clair River     Outflow LH  4.782001e+03  5.060392e+03
# 1                 NaN      US Runoff  5.074288e+00  1.079898e+01
# 2                 NaN      CA Runoff  9.532302e+00  1.026022e+01
# 3                 NaN        Outflow  4.796607e+03  5.081451e+03
# 4      St Clair Basin      US Runoff  2.364030e+01  3.491522e+01
# 5                 NaN      CA Runoff  9.578927e+01  1.131335e+02
# 6                 NaN  Precipitation  2.140406e+01  3.161243e+01
# 7                 NaN    Evaporation  2.701139e+01  3.126095e+01
# 8                 NaN        Outflow  4.910430e+03  5.229851e+03
# 9       Detroit River      US Runoff  1.095573e+01  1.425158e+01
# 10                NaN      CA Runoff  2.329200e+00  4.006997e+00
# 11                NaN        Outflow  4.923714e+03  5.248110e+03
# 12      Western Basin      US Runoff  3.290898e+02  2.667070e+02
# 13                NaN      CA Runoff  1.000000e-09  1.000000e-09
# 14                NaN  Precipitation  6.975589e+01  7.792700e+01
# 15                NaN    Evaporation  6.891057e+01  7.975191e+01
# 16                NaN        Outflow  5.253650e+03  5.512992e+03
# 17      Central Basin      US Runoff  2.495052e+02  2.542191e+02
# 18                NaN      CA Runoff  1.842686e+01  2.137655e+01
# 19                NaN  Precipitation  3.925180e+02  4.384970e+02
# 20                NaN    Evaporation  3.877614e+02  4.487659e+02
# 21                NaN        Outflow  5.526338e+03  5.778319e+03
# 22      Eastern Basin      US Runoff  5.489520e+01  6.260690e+01
# 23                NaN      CA Runoff  8.452079e+01  9.834257e+01
# 24                NaN  Precipitation  1.696035e+02  1.894706e+02
# 25                NaN    Evaporation  1.675482e+02  1.939077e+02
# 26                NaN        Outflow  5.667810e+03  5.934831e+03
# 27            Outflow  Niagara River  5.292348e+03  5.640632e+03
# 28                NaN  Welland Canal  1.996432e+02  2.012751e+02
# 29                NaN    Consumptive  1.060000e+02  1.060000e+02
# 30                NaN          Total  5.597992e+03  5.947907e+03
# 31  Risidual (In-Out)            NaN  6.981785e+01 -1.307589e+01
# 32   Change in WL, cm            NaN -9.200000e+00  1.520000e+01
#
#             2005          2006          2007          2008          2009  \
# 0   5.002331e+03  4.968236e+03  4.804197e+03  4.859677e+03  5.218747e+03
# 1   8.777848e+00  1.301302e+01  6.986587e+00  1.107749e+01  1.445965e+01
# 2   1.407360e+01  1.729470e+01  8.978344e+00  2.169598e+01  1.337226e+01
# 3   5.025183e+03  4.998544e+03  4.820162e+03  4.892451e+03  5.246579e+03
# 4   3.015958e+01  4.218118e+01  3.012674e+01  4.314999e+01  5.817907e+01
# 6   2.539552e+01  2.781971e+01  3.548753e+01  3.241655e+01
# 7   3.094727e+01  3.710623e+01  3.135207e+01  3.134880e+01
# 8   5.558890e+03  6.024871e+03  6.047547e+03  5.277929e+03
# 9   1.247830e+01  1.279497e+01  1.494314e+01  1.430740e+01
# 10  3.490800e+00  3.642475e+00  4.569909e+00  3.890663e+00
# 11  5.574859e+03  6.041309e+03  6.067060e+03  5.296127e+03
# 12  3.363750e+02  2.188463e+02  3.686993e+02  3.126530e+02
# 13  1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
# 14  7.987448e+01  8.461530e+01  1.029921e+02  8.713279e+01
# 15  7.895165e+01  9.466420e+01  7.998436e+01  7.997602e+01
# 16  5.912157e+03  6.250106e+03  6.458767e+03  5.615937e+03
# 17  1.930972e+02  1.568769e+02  2.351671e+02  2.348571e+02
# 18  1.532505e+01  1.734876e+01  2.113661e+01  2.296725e+01
# 19  4.494555e+02  4.761323e+02  5.795388e+02  4.902982e+02
# 20  4.442628e+02  5.326776e+02  4.500738e+02  4.500269e+02
# 21  6.125772e+03  6.367786e+03  6.844536e+03  5.914033e+03
# 22  4.492532e+01  3.808085e+01  6.576091e+01  5.282610e+01
# 23  7.423966e+01  8.935626e+01  1.186345e+02  1.025788e+02
# 24  1.942057e+02  2.057325e+02  2.504135e+02  2.118535e+02
# 25  1.919620e+02  2.301652e+02  1.944729e+02  1.944526e+02
# 26  6.247181e+03  6.470791e+03  7.084872e+03  6.086838e+03
# 27  6.137914e+03  6.364727e+03  6.832589e+03  5.828533e+03
# 28  2.248479e+02  2.077975e+02  1.387766e+02  1.906834e+02
# 29  1.060000e+02  1.060000e+02  1.060000e+02  1.060000e+02
# 30  6.468762e+03  6.678524e+03  7.077366e+03  6.125216e+03
# 31 -2.215812e+02 -2.077332e+02  7.506274e+00  1.720370e+02
# 32  1.080000e+01  9.100000e+00  1.710000e+01  1.010667e+01

# %%
(table.iloc[idx][2:-1] )/\
                (table.iloc[idx][-1] )*100 - 100
# Out:
# 2003   -33.9718
# 2004   -2.48058
# 2005   -15.7633
# 2006    17.8135
# 2007    -15.855
# 2008    20.5194
# 2009    62.4961
# 2010   -26.6855
# 2011    52.1082
# 2012   -36.1485
# 2013   -2.17413
# 2014    6.50734
# 2015   -21.6588
# 2016   -14.1805
# 2017     9.4735
# Name: 6, dtype: object

# %%
f, axes = plt.subplots(2,2, figsize=(1*2,1*2), dpi=600, sharex=True, sharey=True)

labels = ['US$^\star$', 'CA$^\star$', 'P', 'E']
colors = [0,3,1,2]
strartin_idx = 4

data = [
    ((table.iloc[4][2:-1]+table.iloc[1][2:-1])/(table.iloc[4][-1]+table.iloc[1][-1])*100 - 100, table.iloc[4][-1]+table.iloc[1][-1]),
    ((table.iloc[5][2:-1]+table.iloc[2][2:-1])/(table.iloc[5][-1]+table.iloc[2][-1])*100 - 100, table.iloc[5][-1]+table.iloc[2][-1]),
    (table.iloc[6][2:-1]/table.iloc[6][-1]*100 - 100, table.iloc[6][-1]),
    (table.iloc[7][2:-1]/table.iloc[7][-1]*100 - 100, table.iloc[7][-1]),
]


for i,ax1 in enumerate(axes):
    for j, ax in enumerate(ax1):
        ax.axhline(0, c='k', ls='--', lw=0.3)
        ax.plot(data[(i+1)*i+j][0], lw=1, label='St.Clair', c='k')#c=sns.color_palette()[colors[(i+1)*i+j]])
        ax.set_xlabel('')
        # axes.grid(lw=0.2)
        # axes.set_ylim(-15,15)
        # axes.set_xlim(3,17)
        # axes.set_ylabel('%')
        ax.yaxis.set_tick_params(width=0.3)
        for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(0.3)
        ax.text(0.5,1.1, labels[(i+1)*i+j], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.text(1.2,0.38, str(round(data[(i+1)*i+j][1])).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, weight='bold')
        ax.set_xlabel('')
        # plt.xticks(rotation='45')
        # axes.legend(loc=2, frameon=1, framealpha=1)
        ax.get_xaxis().set_ticks([])
        ax.get_yaxis().set_ticklabels(['0', '50%'])

plt.subplots_adjust(hspace=.7, wspace=.9, left=0.2, right=0.88)
sns.despine(offset=1, trim=True,bottom=True);
# plt.tight_layout()
f.savefig('img/clair_lake.pdf')

# %%
table.iloc[8]
# Out:
# RWB         NaN
# HC      Outflow
# 2003    4910.43
# 2004    5229.85
# 2005    5165.26
# 2006    5210.03
# 2007    4932.48
# 2008    5118.06
# 2009    5469.41
# 2010    5118.87
# 2011    5020.27
# 2012    4959.21
# 2013    5024.31
# 2014    5379.45
# 2015    5558.89
# 2016    6024.87
# 2017    6047.55
# Mean    5277.93
# Name: 8, dtype: object

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(table.iloc[8][2:-1]/table.iloc[8][-1]*100 - 100, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/detroit_river.pdf')

# %%
f, axes = plt.subplots(2,2, figsize=(1*2,1*2), dpi=600, sharex=True, sharey=True)

labels = ['US$^\star$', 'CA$^\star$', 'P', 'E']
colors = [0,3,1,2]

data = [
    ((table.iloc[9][2:-1]+table.iloc[12][2:-1])/(table.iloc[9][-1]+table.iloc[12][-1])*100 - 100, table.iloc[9][-1]+table.iloc[12][-1]),
    ((table.iloc[10][2:-1]+table.iloc[13][2:-1])/(table.iloc[10][-1]+table.iloc[13][-1])*100 - 100, table.iloc[10][-1]+table.iloc[13][-1]),
    (table.iloc[14][2:-1]/table.iloc[14][-1]*100 - 100, table.iloc[14][-1]),
    (table.iloc[15][2:-1]/table.iloc[15][-1]*100 - 100, table.iloc[15][-1]),
]


for i,ax1 in enumerate(axes):
    for j, ax in enumerate(ax1):
        ax.axhline(0, c='k', ls='--', lw=0.3)
        ax.plot(data[(i+1)*i+j][0], lw=1, label='St.Clair', c='k')#c=sns.color_palette()[colors[(i+1)*i+j]])
        ax.set_xlabel('')
        # axes.grid(lw=0.2)
        # axes.set_ylim(-15,15)
        # axes.set_xlim(3,17)
        # axes.set_ylabel('%')
        ax.yaxis.set_tick_params(width=0.3)
        for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(0.3)
        ax.text(0.5,1.1, labels[(i+1)*i+j], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.text(1.25,0.3, str(round(data[(i+1)*i+j][1])).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, weight='bold')
        ax.set_xlabel('')
        # plt.xticks(rotation='45')
        # axes.legend(loc=2, frameon=1, framealpha=1)
        ax.get_xaxis().set_ticks([])
        ax.get_yaxis().set_ticklabels(['0', '50%'])

plt.subplots_adjust(hspace=.7, wspace=.9, left=0.2, right=0.88)
sns.despine(offset=1, trim=True,bottom=True);
# plt.tight_layout()
# f.savefig('img/clair_lake.pdf')


f.savefig('img/western.pdf')

# %%
table.iloc[16]
# Out:
# RWB         NaN
# HC      Outflow
# 2003    5253.65
# 2004    5512.99
# 2005    5469.15
# 2006    5588.47
# 2007    5316.14
# 2008    5532.75
# 2009    5798.67
# 2010    5366.96
# 2011    5605.72
# 2012    5130.55
# 2013     5347.7
# 2014    5695.26
# 2015    5912.16
# 2016    6250.11
# 2017    6458.77
# Mean    5615.94
# Name: 16, dtype: object

# %%
w_to_c = table.iloc[16]

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(w_to_c[2:-1]/w_to_c[-1]*100 - 100, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/w_to_c.pdf')

# %%
f, axes = plt.subplots(2,2, figsize=(1*2,1*2), dpi=600, sharex=True, sharey=True)

labels = ['US', 'CA', 'P', 'E']
colors = [0,3,1,2]
strartin_idx = 17
for i,ax1 in enumerate(axes):
    for j, ax in enumerate(ax1):
        ax.axhline(0, c='k', ls='--', lw=0.3)
        ax.plot(table.iloc[(i+1)*i+j+strartin_idx][2:-1]/table.iloc[(i+1)*i+j+strartin_idx][-1]*100 - 100, lw=1, label='St.Clair', c='k')#c=sns.color_palette()[colors[(i+1)*i+j]])
        ax.set_xlabel('')
        # axes.grid(lw=0.2)
        # axes.set_ylim(-15,15)
        # axes.set_xlim(3,17)
        # axes.set_ylabel('%')
        ax.yaxis.set_tick_params(width=0.3)
        for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(0.3)
        ax.text(0.5,1.1, labels[(i+1)*i+j], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.text(1.25,0.35, str(round(table.iloc[(i+1)*i+j+strartin_idx][-1])).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, weight='bold')
        ax.set_xlabel('')
        # plt.xticks(rotation='45')
        # axes.legend(loc=2, frameon=1, framealpha=1)
        # axes.get_xaxis().set_ticklabels([])
        ax.get_xaxis().set_ticks([])
        ax.get_yaxis().set_ticklabels(['0', '50%'])

plt.subplots_adjust(hspace=.7, wspace=.9, left=0.2, right=0.88)
sns.despine(offset=1, trim=True,bottom=True);
# plt.tight_layout()
f.savefig('img/central.pdf')

# %%
c_to_e = table.iloc[21]

# %%
c_to_e
# Out:
# RWB         NaN
# HC      Outflow
# 2003    5526.34
# 2004    5778.32
# 2005    5703.66
# 2006    5946.83
# 2007    5594.71
# 2008    5941.97
# 2009    6080.77
# 2010     5556.7
# 2011    6260.93
# 2012     5275.3
# 2013    5693.79
# 2014    6013.09
# 2015    6125.77
# 2016    6367.79
# 2017    6844.54
# Mean    5914.03
# Name: 21, dtype: object

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(c_to_e[2:-1]/c_to_e[-1]*100 - 100, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/c_to_e.pdf')

# %%
f, axes = plt.subplots(2,2, figsize=(1*2,1*2), dpi=600, sharex=True, sharey=True)

labels = ['US', 'CA', 'P', 'E']
colors = [0,3,1,2]
strartin_idx = 22
for i,ax1 in enumerate(axes):
    for j, ax in enumerate(ax1):
        ax.axhline(0, c='k', ls='--', lw=0.3)
        ax.plot(table.iloc[(i+1)*i+j+strartin_idx][2:-1]/table.iloc[(i+1)*i+j+strartin_idx][-1]*100 - 100, lw=1, label='St.Clair', c='k')#c=sns.color_palette()[colors[(i+1)*i+j]])
        ax.set_xlabel('')
        # axes.grid(lw=0.2)
        # axes.set_ylim(-15,15)
        # axes.set_xlim(3,17)
        # axes.set_ylabel('%')
        ax.yaxis.set_tick_params(width=0.3)
        for axis in ['top','bottom','left','right']:
            ax.spines[axis].set_linewidth(0.3)
        ax.text(0.5,1.1, labels[(i+1)*i+j], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes)
        ax.text(1.25,0.48, str(round(table.iloc[(i+1)*i+j+strartin_idx][-1])).split('.')[0], horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, weight='bold')
        ax.set_xlabel('')
        # plt.xticks(rotation='45')
        # axes.legend(loc=2, frameon=1, framealpha=1)
        # axes.get_xaxis().set_ticklabels([])
        ax.get_xaxis().set_ticks([])
        ax.set_ylim(-50,50)
        ax.get_yaxis().set_ticks([0,50])
        ax.get_yaxis().set_ticklabels(['0', '50%'])

plt.subplots_adjust(hspace=.7, wspace=.9, left=0.2, right=0.88)
sns.despine(offset=1, trim=True,bottom=True);
# plt.tight_layout()
f.savefig('img/eastern.pdf')

# %%
table.iloc[30]
# Out:
# RWB         NaN
# HC        Total
# 2003    5597.99
# 2004    5947.91
# 2005    6038.07
# 2006    5949.39
# 2007       5885
# 2008    6026.84
# 2009    6179.48
# 2010       5821
# 2011    6186.29
# 2012    5980.31
# 2013     5870.5
# 2014    6170.81
# 2015    6468.76
# 2016    6678.52
# 2017    7077.37
# Mean    6125.22
# Name: 30, dtype: object

# %%
niagara = table.iloc[26]

# %%
f, axes = plt.subplots(1,1, figsize=(1,0.65), dpi=600, sharex=True)

axes.axhline(0, c='k', ls='--', lw=0.3)
axes.plot(niagara[2:-1]/niagara[-1]*100 - 100, lw=1, c='k', label='St.Clair')
axes.set_xlabel('')
# axes.grid(lw=0.2)
# axes.set_ylim(-15,15)
# axes.set_xlim(3,17)
# axes.set_ylabel('%')
for axis in ['top','bottom','left','right']:
    axes.spines[axis].set_linewidth(0.3)
axes.yaxis.set_tick_params(width=0.3)
axes.set_xlabel('')
# plt.xticks(rotation='45')
# axes.legend(loc=2, frameon=1, framealpha=1)
# axes.get_xaxis().set_ticklabels([])
axes.get_xaxis().set_ticks([])
axes.get_yaxis().set_ticks([-10,10])
axes.get_yaxis().set_ticklabels(['-10%', '10%'])
sns.despine(offset=1, trim=True,bottom=True);
plt.tight_layout()
f.savefig('img/niagara.pdf')

# %%
niagara[-1]
# Out:
# 6050.179226301336
