# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set_style("whitegrid")
plt.rcParams.update({'font.size': 32})
sns.set_context("poster", rc={"font.size":34,"axes.titlesize":34,"axes.labelsize":34, "lines.linewidth": 2})  
plt.rcParams['figure.figsize'] = 18, 12

pd.options.display.max_columns = 999
pd.options.display.max_rows = 9999


from datetime import datetime
str(datetime.now())
# Out:
# '2018-06-27 11:45:51.631007'

# %%
df = pd.read_csv('../../measurements/Excel Files/task 1/Basins averages/eastern_basin_average.csv', )

# %%
df.tail()
# Out:
#        YYYY  MM  DD         WDIR         WSPD          GST WVHT  DPD  APD  \
# 11441  2015  12  27   199.506709     4.630625  6.120833334  NAN  NAN  NAN
# 11442  2015  12  28   74.5010965  7.338642473  11.00409946  NAN  NAN  NAN
# 11443  2015  12  29  177.3843583  6.935233612  11.66273536  NAN  NAN  NAN
# 11444  2015  12  30  231.3181023  4.109166667  5.887083333  NAN  NAN  NAN
# 11445  2015  12  31  253.1705182  8.174166669  10.59916667  NAN  NAN  NAN
#
#        MWD         PRES         ATMP WTMP DEWP  VIS TIDE
# 11441  NAN   1015.97072  7.216666667  NAN  NAN  NAN  NAN
# 11442  NAN  1027.539852  0.320833333  NAN  NAN  NAN  NAN
# 11443  NAN     1011.475         5.25  NAN  NAN  NAN  NAN
# 11444  NAN  1020.442966  3.966666667  NAN  NAN  NAN  NAN
# 11445  NAN  1019.438958       2.9375  NAN  NAN  NAN  NAN

# %%
df = df.dropna(subset=['YYYY', 'MM', 'DD'])

# %%
df.tail()
# Out:
#        YYYY  MM  DD         WDIR         WSPD          GST WVHT  DPD  APD  \
# 11441  2015  12  27   199.506709     4.630625  6.120833334  NAN  NAN  NAN
# 11442  2015  12  28   74.5010965  7.338642473  11.00409946  NAN  NAN  NAN
# 11443  2015  12  29  177.3843583  6.935233612  11.66273536  NAN  NAN  NAN
# 11444  2015  12  30  231.3181023  4.109166667  5.887083333  NAN  NAN  NAN
# 11445  2015  12  31  253.1705182  8.174166669  10.59916667  NAN  NAN  NAN
#
#        MWD         PRES         ATMP WTMP DEWP  VIS TIDE
# 11441  NAN   1015.97072  7.216666667  NAN  NAN  NAN  NAN
# 11442  NAN  1027.539852  0.320833333  NAN  NAN  NAN  NAN
# 11443  NAN     1011.475         5.25  NAN  NAN  NAN  NAN
# 11444  NAN  1020.442966  3.966666667  NAN  NAN  NAN  NAN
# 11445  NAN  1019.438958       2.9375  NAN  NAN  NAN  NAN

# %%
from datetime import datetime


df['Date'] = df.apply(lambda x:datetime.strptime("{0} {1} {2} 00:00:00".format(x['YYYY'],x['MM'], x['DD']), "%Y %m %d %H:%M:%S"),axis=1)
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.head()
# Out:
#    YYYY MM DD         WDIR         WSPD          GST WVHT  DPD  APD  MWD  \
# 1  1983  4  1  90.41666667  3.808333333  4.270833333  NAN  NAN  NAN  NAN
# 2  1983  4  2  87.91666667  6.379166667  8.170833333  NAN  NAN  NAN  NAN
# 3  1983  4  3  139.5833333  4.158333333  5.816666667  NAN  NAN  NAN  NAN
# 4  1983  4  4       223.75  8.870833333  10.15833333  NAN  NAN  NAN  NAN
# 5  1983  4  5  235.6521739  5.839130435  6.556521739  NAN  NAN  NAN  NAN
#
#           PRES         ATMP WTMP DEWP  VIS TIDE       Date
# 1  1015.229167  2.420833333  NAN  NAN  NAN  NAN 1983-04-01
# 2    1011.5625       7.0875  NAN  NAN  NAN  NAN 1983-04-02
# 3     999.9875  7.183333333  NAN  NAN  NAN  NAN 1983-04-03
# 4  1011.545833  4.991666667  NAN  NAN  NAN  NAN 1983-04-04
# 5  1021.156522  4.530434783  NAN  NAN  NAN  NAN 1983-04-05

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#             YYYY MM DD         WDIR         WSPD          GST WVHT  DPD  APD  \
# Date
# 1983-04-01  1983  4  1  90.41666667  3.808333333  4.270833333  NAN  NAN  NAN
# 1983-04-02  1983  4  2  87.91666667  6.379166667  8.170833333  NAN  NAN  NAN
# 1983-04-03  1983  4  3  139.5833333  4.158333333  5.816666667  NAN  NAN  NAN
# 1983-04-04  1983  4  4       223.75  8.870833333  10.15833333  NAN  NAN  NAN
# 1983-04-05  1983  4  5  235.6521739  5.839130435  6.556521739  NAN  NAN  NAN
#
#             MWD         PRES         ATMP WTMP DEWP  VIS TIDE
# Date
# 1983-04-01  NAN  1015.229167  2.420833333  NAN  NAN  NAN  NAN
# 1983-04-02  NAN    1011.5625       7.0875  NAN  NAN  NAN  NAN
# 1983-04-03  NAN     999.9875  7.183333333  NAN  NAN  NAN  NAN
# 1983-04-04  NAN  1011.545833  4.991666667  NAN  NAN  NAN  NAN
# 1983-04-05  NAN  1021.156522  4.530434783  NAN  NAN  NAN  NAN

# %%
df2['ATMP'] = pd.to_numeric(df2['ATMP'], errors='coerce')
x2= pd.date_range('1983-04-01','2015-12-31',freq='D')
df2=df2.reindex(x2)

# %%
df2['ATMP'] = df2['ATMP'].interpolate(method='linear', limit=300)

# %%
df2[:300]
# Out:
#             YYYY   MM   DD         WDIR         WSPD          GST WVHT  DPD  \
# 1983-04-01  1983    4    1  90.41666667  3.808333333  4.270833333  NAN  NAN
# 1983-04-02  1983    4    2  87.91666667  6.379166667  8.170833333  NAN  NAN
# 1983-04-03  1983    4    3  139.5833333  4.158333333  5.816666667  NAN  NAN
# 1983-04-04  1983    4    4       223.75  8.870833333  10.15833333  NAN  NAN
# 1983-04-05  1983    4    5  235.6521739  5.839130435  6.556521739  NAN  NAN
# 1983-04-06  1983    4    6  60.41666667       4.3125  4.908333333  NAN  NAN
# 1983-04-07  1983    4    7  167.9166667  4.291666667  5.633333333  NAN  NAN
# 1983-04-08  1983    4    8       201.25  3.966666667  4.454166667  NAN  NAN
# 1983-04-09  1983    4    9  57.36842105  7.115789474  8.205263158  NAN  NAN
# 1983-04-10  1983    4   10  175.8333333       5.0875       7.4125  NAN  NAN
# 1983-04-11  1983    4   11        222.5  6.079166667       7.0625  NAN  NAN
# ...

# %%
for c in df.columns[3:]:
    df2[c] = pd.to_numeric(df2[c], errors='coerce')
    df2[c] = df2[c].interpolate(method='linear', limit=300)

# %%
df2[:300]
# Out:
#             YYYY   MM   DD        WDIR       WSPD        GST  WVHT  DPD  APD  \
# 1983-04-01  1983    4    1   90.416667   3.808333   4.270833   NaN  NaN  NaN
# 1983-04-02  1983    4    2   87.916667   6.379167   8.170833   NaN  NaN  NaN
# 1983-04-03  1983    4    3  139.583333   4.158333   5.816667   NaN  NaN  NaN
# 1983-04-04  1983    4    4  223.750000   8.870833  10.158333   NaN  NaN  NaN
# 1983-04-05  1983    4    5  235.652174   5.839130   6.556522   NaN  NaN  NaN
# 1983-04-06  1983    4    6   60.416667   4.312500   4.908333   NaN  NaN  NaN
# 1983-04-07  1983    4    7  167.916667   4.291667   5.633333   NaN  NaN  NaN
# 1983-04-08  1983    4    8  201.250000   3.966667   4.454167   NaN  NaN  NaN
# 1983-04-09  1983    4    9   57.368421   7.115789   8.205263   NaN  NaN  NaN
# 1983-04-10  1983    4   10  175.833333   5.087500   7.412500   NaN  NaN  NaN
# 1983-04-11  1983    4   11  222.500000   6.079167   7.062500   NaN  NaN  NaN
# ...

# %%
df2.to_csv('test.csv')

# %%
df = pd.read_csv('../../measurements/Excel Files/task 2/relative humidity, solar radiation + others/basin averages/eastern_basin_average.csv', skiprows=9)

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY SRAD     TMAX     TMIN    WIND      TDEW      T2M     RH2M
# 0  1983      1    1  NAN    0.775  -3.8125  4.9250    -3.875  -1.2375    82.45
# 1  1983      1    2  NAN   1.9875  -3.5875  3.8875   -3.9125    -0.35  76.7375
# 2  1983      1    3  NAN  -3.4125     -8.4  3.8875  -10.9375  -5.1875  63.8875
# 3  1983      1    4  NAN   -0.725    -9.25  3.4375  -12.0625   -5.025    57.85
# 4  1983      1    5  NAN    2.825    -4.25  4.0125   -5.4875  -1.1125  72.0125

# %%
df['Date'] = df.apply(lambda x:datetime.strptime("{0} {1} {2} 00:00:00".format(x['YEAR'],x['MONTH'], x['DAY']), "%Y %m %d %H:%M:%S"),axis=1)

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#             YEAR  MONTH  DAY SRAD     TMAX     TMIN    WIND      TDEW  \
# Date
# 1983-01-01  1983      1    1  NAN    0.775  -3.8125  4.9250    -3.875
# 1983-01-02  1983      1    2  NAN   1.9875  -3.5875  3.8875   -3.9125
# 1983-01-03  1983      1    3  NAN  -3.4125     -8.4  3.8875  -10.9375
# 1983-01-04  1983      1    4  NAN   -0.725    -9.25  3.4375  -12.0625
# 1983-01-05  1983      1    5  NAN    2.825    -4.25  4.0125   -5.4875
#
#                 T2M     RH2M
# Date
# 1983-01-01  -1.2375    82.45
# 1983-01-02    -0.35  76.7375
# 1983-01-03  -5.1875  63.8875
# 1983-01-04   -5.025    57.85
# 1983-01-05  -1.1125  72.0125

# %%
x2= pd.date_range('1983-04-01','2015-12-31',freq='D')

# %%
df2=df.reindex(x2)

# %%
df2.head()
# Out:
#             YEAR  MONTH  DAY SRAD     TMAX    TMIN    WIND    TDEW     T2M  \
# 1983-04-01  1983      4    1  NAN    9.075  -1.325  2.2625   -1.75  2.9625
# 1983-04-02  1983      4    2  NAN    9.225  0.7625  5.7875  1.4125    4.95
# 1983-04-03  1983      4    3  NAN   10.975  5.1875  3.7000     5.3  7.2625
# 1983-04-04  1983      4    4  NAN  10.3875  3.3875  4.4875  3.8125  6.0125
# 1983-04-05  1983      4    5  NAN  11.2375  2.0625  2.6875  2.7375  5.8125
#
#                RH2M
# 1983-04-01  70.9875
# 1983-04-02  77.7875
# 1983-04-03  87.4875
# 1983-04-04     85.6
# 1983-04-05   80.575

# %%
for c in df2.columns[3:]:
    df2[c] = pd.to_numeric(df2[c], errors='coerce')
    df2[c] = df2[c].interpolate(method='linear', limit=300)

# %%
df2.head()
# Out:
#             YEAR  MONTH  DAY  SRAD     TMAX    TMIN    WIND    TDEW     T2M  \
# 1983-04-01  1983      4    1   NaN   9.0750 -1.3250  2.2625 -1.7500  2.9625
# 1983-04-02  1983      4    2   NaN   9.2250  0.7625  5.7875  1.4125  4.9500
# 1983-04-03  1983      4    3   NaN  10.9750  5.1875  3.7000  5.3000  7.2625
# 1983-04-04  1983      4    4   NaN  10.3875  3.3875  4.4875  3.8125  6.0125
# 1983-04-05  1983      4    5   NaN  11.2375  2.0625  2.6875  2.7375  5.8125
#
#                RH2M
# 1983-04-01  70.9875
# 1983-04-02  77.7875
# 1983-04-03  87.4875
# 1983-04-04  85.6000
# 1983-04-05  80.5750

# %%
df2.to_csv('test.csv')

# %%
df = pd.read_csv('../../measurements/Excel Files/task 2/precipitation/basin averages/eastern_basin_average.csv', skiprows=0)

# %%
df.tail()
# Out:
#        Year  Month  Day      PRCP        SNOW  Total Precip (mm)  Unnamed: 6  \
# 13051  2017      1    5  0.981818    9.545455          10.527273         NaN
# 13052  2017      1    6  6.580000  160.900000         167.480000         NaN
# 13053  2017      1    7  5.440000   38.333333          43.773333         NaN
# 13054  2017      1    8  1.330000   35.400000          36.730000         NaN
# 13055  2017      1    9  0.190000    4.200000           4.390000         NaN
#
#        Unnamed: 7
# 13051         NaN
# 13052         NaN
# 13053         NaN
# 13054         NaN
# 13055         NaN

# %%
# for c in df.columns[:3]:
#     df[c] = pd.to_numeric(df[c], errors='coerce')
df['Date'] = df.apply(lambda x:datetime.strptime("{0} {1} {2} 00:00:00".format(int(x['Year']),int(x['Month']), int(x['Day'])), "%Y %m %d %H:%M:%S"),axis=1)
df.set_index('Date', inplace=True)
x2= pd.date_range('1983-04-01','2015-12-31',freq='D')
df2=df.reindex(x2)
for c in df2.columns[3:]:
    df2[c] = pd.to_numeric(df2[c], errors='coerce')
    df2[c] = df2[c].interpolate(method='linear', limit=300)
df2.head()
# Out:
#               Year  Month  Day  PRCP  SNOW  Total Precip (mm)  Unnamed: 6  \
# 1983-04-01  1983.0    4.0  1.0   0.0   0.0                0.0         NaN
# 1983-04-02  1983.0    4.0  2.0  10.4   0.0               10.4         NaN
# 1983-04-03  1983.0    4.0  3.0   3.0   0.0                3.0         NaN
# 1983-04-04  1983.0    4.0  4.0   0.0   0.0                0.0         NaN
# 1983-04-05  1983.0    4.0  5.0   0.6   0.0                0.6         NaN
#
#             Unnamed: 7
# 1983-04-01         NaN
# 1983-04-02         NaN
# 1983-04-03         NaN
# 1983-04-04         NaN
# 1983-04-05         NaN

# %%
df2.to_csv('test.csv')

# %%
df = pd.read_csv('../../measurements/Excel Files/task 2/cloud cover/basin averages/western_basin_average.csv', skiprows=0)

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  Cloud Cover (Fraction)
# 0  2006    1.0  1.0                0.806058
# 1  2006    1.0  2.0                0.981121
# 2  2006    1.0  3.0                0.999825
# 3  2006    1.0  4.0                0.995304
# 4  2006    1.0  5.0                0.933908

# %%
df['Date'] = df.apply(lambda x:datetime.strptime("{0} {1} {2} 00:00:00".format(int(x['YEAR']),int(x['MONTH']), int(x['DAY'])), "%Y %m %d %H:%M:%S"),axis=1)
df.set_index('Date', inplace=True)
x2= pd.date_range('1983-04-01','2015-12-31',freq='D')
df2=df.reindex(x2)
for c in df2.columns[3:]:
    df2[c] = pd.to_numeric(df2[c], errors='coerce')
    df2[c] = df2[c].interpolate(method='linear', limit=300)
df2.head()
# Out:
#             YEAR  MONTH  DAY  Cloud Cover (Fraction)
# 1983-04-01   NaN    NaN  NaN                     NaN
# 1983-04-02   NaN    NaN  NaN                     NaN
# 1983-04-03   NaN    NaN  NaN                     NaN
# 1983-04-04   NaN    NaN  NaN                     NaN
# 1983-04-05   NaN    NaN  NaN                     NaN

# %%
df2.to_csv('test.csv')

# %%
df = pd.read_csv('../../measurements/Excel Files/weather combinations/central_basin_weather_average.csv', skiprows=0)

# %%
df.head()
# Out:
#    Year  Month  Day  Cloud Cover(fraction)  \
# 0  1980      1    1                    NaN
# 1  1980      1    2                    NaN
# 2  1980      1    3                    NaN
# 3  1980      1    4                    NaN
# 4  1980      1    5                    NaN
#
#    SRAD Daily Insolation Incident On A Horizontal Surface (MJ/m^2/day)   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    TMAX Maximum Air Temperature At 2 m Above The Surface Of The Earth (degrees C)   \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
# for c in df.columns[:3]:
#     df[c] = pd.to_numeric(df[c], errors='coerce')
df['Date'] = df.apply(lambda x:datetime.strptime("{0} {1} {2} 00:00:00".format(int(x['Year']),int(x['Month']), int(x['Day'])), "%Y %m %d %H:%M:%S"),axis=1)
df.set_index('Date', inplace=True)
x2= pd.date_range('1983-04-01','2015-12-31',freq='D')
df2=df.reindex(x2)
for c in df2.columns[3:]:
    df2[c] = pd.to_numeric(df2[c], errors='coerce')
    df2[c] = df2[c].interpolate(method='linear', limit=10)
df2.head()
# Out:
#             Year  Month  Day  Cloud Cover(fraction)  \
# 1983-04-01  1983      4    1                    NaN
# 1983-04-02  1983      4    2                    NaN
# 1983-04-03  1983      4    3                    NaN
# 1983-04-04  1983      4    4                    NaN
# 1983-04-05  1983      4    5                    NaN
#
#             SRAD Daily Insolation Incident On A Horizontal Surface (MJ/m^2/day)   \
# 1983-04-01                                                NaN
# 1983-04-02                                                NaN
# 1983-04-03                                                NaN
# 1983-04-04                                                NaN
# 1983-04-05                                                NaN
#
#             TMAX Maximum Air Temperature At 2 m Above The Surface Of The Earth (degrees C)   \
# 1983-04-01                                            10.3625
# 1983-04-02                                             8.8125
# ...

# %%
df2.to_csv('test.csv')

# %%
df2[df2.Year>2012].plot(y='PRCP')

# %%
df = pd.read_csv('../../../MyLake-Erie/IO/erie_eastern.txt', skiprows=1, delimiter='\t')

# %%
df.plot(y='CloudCover')
