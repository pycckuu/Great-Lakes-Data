# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set_style("whitegrid")
plt.rcParams.update({'font.size': 32})
sns.set_context("poster", rc={"font.size":34,"axes.titlesize":34,"axes.labelsize":34, "lines.linewidth": 2})  
plt.rcParams['figure.figsize'] = 18, 12

pd.options.display.max_columns = 999
pd.options.display.max_rows = 100


from datetime import datetime
str(datetime.now())
# Out:
# '2018-05-11 15:23:49.491535'

# %%
df = pd.read_csv('../../measurements/GLNPO/glenda O2.csv')

# %%
df[df.STATION_ID=='ER15M'][['SAMPLING_DATE','SAMPLE_DEPTH_M', 'VALUE_1']].plot.density()

# %%
for d in x
df[df.STATION_ID=='ER15M'].SAMPLE_DEPTH_M
# Out:
#   File "<ipython-input-5-9d4ebcd67887>", line 1
#     for d in x
#               ^
# SyntaxError: invalid syntax

# %%
df.columns
# Out:
# Index(['Row', 'YEAR', 'MONTH', 'LAKE', 'CRUISE_ID', 'VISIT_ID', 'STATION_ID',
#        'STN_DEPTH_M', 'LATITUDE', 'LONGITUDE', 'SAMPLING_DATE', 'TIME_ZONE',
#        'SAMPLE_DEPTH_M', 'DEPTH_CODE', 'MEDIUM', 'SAMPLE_TYPE', 'QC_TYPE',
#        'SAMPLE_ID', 'ANL_CODE_1', 'ANALYTE_1', 'VALUE_1', 'UNITS_1',
#        'FRACTION_1', 'METHOD_1', 'RESULT_REMARK_1', 'Unnamed: 25'],
#       dtype='object')

# %%
import numpy as np

# %%
x = np.linspace(0,58, 15)

# %%
dx = x[1] - x[0]

# %%
# for d in x:
#     try:
for d,c in zip(df[(df.STATION_ID=='ER15M')].SAMPLING_DATE.unique()[:], sns.color_palette("Paired", 10)):
    data = df[(df.STATION_ID=='ER15M') & (df.SAMPLING_DATE ==d)]
    data.sort(columns='SAMPLE_DEPTH_M', inplace=True)
    plt.scatter(data['VALUE_1'], data['SAMPLE_DEPTH_M'], color=c, label=None)
    plt.plot(data['VALUE_1'], data['SAMPLE_DEPTH_M'], color=c, label=str(d)[:10], lw=5 )
plt.ylabel('Depth, m')
plt.xlabel('Oxygen Concentration, [mg/L]')
plt.legend(frameon=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-14334d557505> in <module>()
#       3 for d,c in zip(df[(df.STATION_ID=='ER15M')].SAMPLING_DATE.unique()[:], sns.color_palette("Paired", 10)):
#       4     data = df[(df.STATION_ID=='ER15M') & (df.SAMPLING_DATE ==d)]
# ----> 5     data.sort(columns='SAMPLE_DEPTH_M', inplace=True)
#       6     plt.scatter(data['VALUE_1'], data['SAMPLE_DEPTH_M'], color=c, label=None)
#       7     plt.plot(data['VALUE_1'], data['SAMPLE_DEPTH_M'], color=c, label=str(d)[:10], lw=5 )
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# ...

# %%
df.DEPTH_CODE.unique()

# %%
data = df[(df.STATION_ID=='ER15M')]
for dc in data.DEPTH_CODE.unique()[1:7]:
    d = data[data.DEPTH_CODE == dc]
#     d.sort(columns='SAMPLING_DATE', inplace=True)
    plt.plot(d['SAMPLING_DATE'].values, d['VALUE_1'].values, lw=5, label=dc)
plt.legend(frameon=1)
plt.ylabel('Oxygen concentration, [mg/L]')
# plt.ylim(8,14)

# %%
data.DEPTH_CODE.unique()

# %%
data[data.DEPTH_CODE == d]['VALUE_1']

# %%
df['SAMPLING_DATE'] =  pd.to_datetime(df['SAMPLING_DATE'], format='%Y/%m/%d %H:%M')

# %%
df.SAMPLING_DATE.unique()
