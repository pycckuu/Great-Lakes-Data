# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

sns.set_style("whitegrid")
plt.rcParams.update({'font.size': 32})
sns.set_context("poster", rc={"font.size":34,"axes.titlesize":34,"axes.labelsize":34, "lines.linewidth": 2})  
plt.rcParams['figure.figsize'] = 18, 12


from datetime import datetime
str(datetime.now())
# Out:
# '2018-08-10 14:29:32.229796'

# %%
df = pd.read_csv('../../measurements/GLNPO/Glenda oxygen.csv')

# %%
df.groupby(['STATION_ID']).count()
# Out:
#             Row  YEAR  MONTH  SEASON  LAKE  CRUISE_ID  VISIT_ID  STN_DEPTH_M  \
# STATION_ID
# ER09          8     8      8       8     8          8         8            8
# ER10          6     6      6       6     6          6         6            6
# ER15M        18    18     18      18    18         18        18           18
# ER30         38    38     38      38    38         38        38           38
# ER31         33    33     33      33    33         33        33           33
# ER32         33    33     33      33    33         33        33           33
# ER36         33    33     33      33    33         33        33           33
# ER37         32    32     32      32    32         32        32           32
# ER38         35    35     35      35    35         35        35           35
# ER42         30    30     30      30    30         30        30           30
# ER43         31    31     31      31    31         31        31           31
# ...

# %%
df[df['STATION_ID']=='ER63'].groupby(['YEAR']).count()
# Out:
#       Row  MONTH  SEASON  LAKE  CRUISE_ID  VISIT_ID  STATION_ID  STN_DEPTH_M  \
# YEAR
# 2000    4      4       4     4          4         4           4            4
# 2002    1      1       1     1          1         1           1            1
# 2004    1      1       1     1          1         1           1            1
# 2005    2      2       2     2          2         2           2            2
# 2006    1      1       1     1          1         1           1            1
# 2010    2      2       2     2          2         2           2            2
#
#       LATITUDE  LONGITUDE     ...       METHOD_3  RESULT_REMARK_3  ANL_CODE_4  \
# YEAR                          ...
# 2000         4          4     ...              0                0           0
# 2002         1          1     ...              0                0           0
# 2004         1          1     ...              0                0           0
# ...

# %%
df.columns[10:]
# Out:
# Index(['LONGITUDE', 'SAMPLING_DATE', 'TIME_ZONE', 'SAMPLE_DEPTH_M',
#        'DEPTH_CODE', 'MEDIUM', 'SAMPLE_TYPE', 'QC_TYPE', 'SAMPLE_ID',
#        'ANL_CODE_1', 'ANALYTE_1', 'VALUE_1', 'UNITS_1', 'FRACTION_1',
#        'METHOD_1', 'RESULT_REMARK_1', 'ANL_CODE_2', 'ANALYTE_2', 'VALUE_2',
#        'UNITS_2', 'FRACTION_2', 'METHOD_2', 'RESULT_REMARK_2', 'ANL_CODE_3',
#        'ANALYTE_3', 'VALUE_3', 'UNITS_3', 'FRACTION_3', 'METHOD_3',
#        'RESULT_REMARK_3', 'ANL_CODE_4', 'ANALYTE_4', 'VALUE_4', 'UNITS_4',
#        'FRACTION_4', 'METHOD_4', 'RESULT_REMARK_4', 'Unnamed: 47'],
#       dtype='object')

# %%
df[df['STATION_ID']=='ER15M'].groupby(['YEAR', 'MONTH', 'SAMPLE_DEPTH_M']).count()
# Out:
#                                Row  SEASON  LAKE  CRUISE_ID  VISIT_ID  \
# YEAR MONTH     SAMPLE_DEPTH_M
# 2000 April     60.000            1       1     1          1         1
#      August    1.048             2       2     2          2         2
#                60.095            2       2     2          2         2
# 2001 April     60.300            1       1     1          1         1
#      August    57.600            1       1     1          1         1
# 2002 April     58.000            1       1     1          1         1
#      August    1.000             1       1     1          1         1
# 2003 April     60.800            1       1     1          1         1
#                61.000            1       1     1          1         1
#      August    1.000             1       1     1          1         1
# 2004 August    2.000             1       1     1          1         1
# 2005 April     58.100            1       1     1          1         1
# ...

# %%
df2=df[pd.to_numeric(df['SAMPLE_DEPTH_M'], errors='coerce').notnull()]
df2=df2[pd.to_numeric(df2['VALUE_1'], errors='coerce').notnull()]
df2['SAMPLE_DEPTH_M']=df2[['SAMPLE_DEPTH_M']].apply(pd.to_numeric)
df2['SAMPLE_DEPTH_M']=df2[['SAMPLE_DEPTH_M']]*-1
df2['VALUE_1']=df2[['VALUE_1']].apply(pd.to_numeric)

# %%
a = df2[df2['STATION_ID']=='ER15M']['SAMPLING_DATE'].unique()

# %%
np.sort(a)
# Out:
# array(['2000/04/16 19:32', '2000/08/04 17:39', '2000/08/04 17:44',
#        '2001/04/15 09:36', '2001/08/05 07:30', '2002/04/08 12:26',
#        '2002/08/07 18:32', '2003/04/15 07:43', '2003/04/18 23:46',
#        '2003/08/09 04:07', '2004/08/07 03:30', '2005/04/12 01:30',
#        '2005/08/11 04:45', '2007/08/09 05:40', '2012/04/09 02:55',
#        '2012/08/11 04:45'], dtype=object)

# %%
df2[(df2['STATION_ID']=='ER15M') & ((df2['MONTH']=='April') | (df2['MONTH']=='August'))].groupby(['YEAR', 'MONTH', 'SAMPLE_DEPTH_M']).mean()['VALUE_1']
# Out:
# Series([], Name: VALUE_1, dtype: float64)

# %%
df2[((df2['STATION_ID']=='ER15M') | (df2['STATION_ID']=='ER63') | (df2['STATION_ID']=='ER09') | (df2['STATION_ID']=='ER10') | (df2['STATION_ID']=='ER93B')) & ((df2['MONTH']=='April    ') | (df2['MONTH']=='August   '))].groupby(['YEAR', 'MONTH', 'SAMPLE_DEPTH_M']).mean()['VALUE_1'].unstack(level=0).unstack(level=0).to_csv('ox_all_ee_glenda.csv')

# %%
df2[(df2['STATION_ID']=='ER15M') | (df2['STATION_ID']=='ER63') | (df2['STATION_ID']=='ER09') | (df2['STATION_ID']=='ER10') | (df2['STATION_ID']=='ER93B')].groupby(['YEAR','MONTH', 'SAMPLE_DEPTH_M']).mean()['VALUE_1'].unstack(level=0).unstack(level=0).dropna(axis=1,how='all').to_csv('glenda_oxygen_ee.csv')

# %%
df2.columns
# Out:
# Index(['Row', 'YEAR', 'MONTH', 'SEASON', 'LAKE', 'CRUISE_ID', 'VISIT_ID',
#        'STATION_ID', 'STN_DEPTH_M', 'LATITUDE', 'LONGITUDE', 'SAMPLING_DATE',
#        'TIME_ZONE', 'SAMPLE_DEPTH_M', 'DEPTH_CODE', 'MEDIUM', 'SAMPLE_TYPE',
#        'QC_TYPE', 'SAMPLE_ID', 'ANL_CODE_1', 'ANALYTE_1', 'VALUE_1', 'UNITS_1',
#        'FRACTION_1', 'METHOD_1', 'RESULT_REMARK_1', 'ANL_CODE_2', 'ANALYTE_2',
#        'VALUE_2', 'UNITS_2', 'FRACTION_2', 'METHOD_2', 'RESULT_REMARK_2',
#        'ANL_CODE_3', 'ANALYTE_3', 'VALUE_3', 'UNITS_3', 'FRACTION_3',
#        'METHOD_3', 'RESULT_REMARK_3', 'ANL_CODE_4', 'ANALYTE_4', 'VALUE_4',
#        'UNITS_4', 'FRACTION_4', 'METHOD_4', 'RESULT_REMARK_4', 'Unnamed: 47'],
#       dtype='object')

# %%
df2[(df2['STATION_ID']=='ER15M') | (df2['STATION_ID']=='ER63') | (df2['STATION_ID']=='ER09') | (df2['STATION_ID']=='ER10') | (df2['STATION_ID']=='ER93B')].groupby(['YEAR', 'MONTH', 'SAMPLE_DEPTH_M']).mean()['VALUE_1'].unstack(level=0).unstack(level=0).to_csv('oxygen_test.csv')
