# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('../../measurements/GLNPO/glenda O2.csv')

# %%
for d in df[df.LAKE=='Erie'].STATION_ID.unique():
    df[(df.LAKE=='Erie') & (df.STATION_ID==d)].plot(x='SAMPLING_DATE', y='VALUE_1')
    plt.show()

# %%
df[df.STATION_ID=='ER15M']
# Out:
#        Row  YEAR      MONTH  LAKE  CRUISE_ID VISIT_ID STATION_ID  STN_DEPTH_M  \
# 458    459  2010  April      Erie     ER1011  E015M10      ER15M         64.4
# 467    468  2010  April      Erie     ER1011  E015M10      ER15M         64.4
# 468    469  2010  April      Erie     ER1011  E015M10      ER15M         64.4
# 469    470  2010  April      Erie     ER1011  E015M10      ER15M         64.4
# 470    471  2010  April      Erie     ER1011  E015M10      ER15M         64.4
# 471    472  2010  April      Erie     ER1011  E015M10      ER15M         64.4
# 472    473  2010  April      Erie     ER1011  E015M10      ER15M         64.4
# 473    474  2010  April      Erie     ER1011  E015M10      ER15M         64.4
# 474    475  2010  April      Erie     ER1011  E015M10      ER15M         64.4
# 560    561  2010  August     Erie     ER1021  E015G10      ER15M         63.2
# 572    573  2010  August     Erie     ER1021  E015G10      ER15M         63.2
# ...

# %%
df[df.LAKE=='Erie'].groupby('STATION_ID').count()
# Out:
#             Row  YEAR  MONTH  LAKE  CRUISE_ID  VISIT_ID  STN_DEPTH_M  \
# STATION_ID
# ER09         56    56     56    56         56        56           56
# ER10         61    61     61    61         61        61           61
# ER15M        86    86     86    86         86        86           86
# ER30         42    42     42    42         42        42           42
# ER31         43    43     43    43         43        43           43
# ER32         36    36     36    36         36        36           36
# ER36         43    43     43    43         43        43           43
# ER37         42    42     42    42         42        42           42
# ER38         45    45     45    45         45        45           45
# ER42         41    41     41    41         41        41           41
# ER43         40    40     40    40         40        40           40
# ER58         34    34     34    34         34        34           34
# ...
