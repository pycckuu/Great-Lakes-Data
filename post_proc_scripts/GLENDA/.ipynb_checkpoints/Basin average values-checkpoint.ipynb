# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set_style("whitegrid")
plt.rcParams.update({'font.size': 32})
sns.set_context("poster", rc={"font.size":34,"axes.titlesize":34,"axes.labelsize":34, "lines.linewidth": 2})  
plt.rcParams['figure.figsize'] = 18, 12

pd.options.display.max_columns = 999
pd.options.display.max_rows = 9999


from datetime import datetime
str(datetime.now())
# Out:
# '2018-05-11 15:30:38.727139'

# %%
from IPython.display import Image
Image(filename='../../measurements/GLNPO/Erie_Summer_Survey2017.jpg')

# %%
df = pd.read_csv('../../measurements/GLNPO/TOTP Eastern Basin.csv')

# %%
df.columns
# Out:
# Index(['Row', 'YEAR', 'MONTH', 'SEASON', 'LAKE', 'CRUISE_ID', 'VISIT_ID',
#        'STATION_ID', 'STN_DEPTH_M', 'LATITUDE', 'LONGITUDE', 'SAMPLING_DATE',
#        'TIME_ZONE', 'SAMPLE_DEPTH_M', 'DEPTH_CODE', 'MEDIUM', 'SAMPLE_TYPE',
#        'QC_TYPE', 'SAMPLE_ID', 'ANL_CODE_1', 'ANALYTE_1', 'VALUE_1', 'UNITS_1',
#        'FRACTION_1', 'METHOD_1', 'RESULT_REMARK_1', 'ANL_CODE_2', 'ANALYTE_2',
#        'VALUE_2', 'UNITS_2', 'FRACTION_2', 'METHOD_2', 'RESULT_REMARK_2',
#        'Unnamed: 33'],
#       dtype='object')

# %%
df.groupby(['YEAR','MONTH','STATION_ID','SAMPLE_DEPTH_M'])['SAMPLE_ID'].nunique()
# Out:
# YEAR  MONTH      STATION_ID  SAMPLE_DEPTH_M
# 1983  April      ER09        0.910             2
#                              20.730            1
#                              21.340            1
#                              32.000            1
#                              33.530            1
#                              40.230            1
#                              40.840            1
#                  ER15M       0.910             2
#                              4.270             2
#                              10.060            2
#                              18.900            1
#                              19.200            1
#                              29.570            1
#                              29.870            1
#                              39.930            1
#                              40.230            1
#                              48.770            1
#                              49.680            1
# ...

# %%
df.VALUE_1.convert_objects(convert_numeric=True).describe()
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# count    2272.000000
# mean        4.915493
# std         2.895032
# min        -0.921000
# 25%         2.600000
# 50%         4.052500
# 75%         7.000000
# max        30.868000
# Name: VALUE_1, dtype: float64

# %%
df.VALUE_1.size
# Out:
# 2300

# %%
import numpy as np

# %%
df.VALUE_1.convert_objects(convert_numeric=True).values
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# array([4.284 , 2.369 , 2.537 , ..., 2.3205, 2.4877, 2.8   ])

# %%
df.columns
# Out:
# Index(['Row', 'YEAR', 'MONTH', 'SEASON', 'LAKE', 'CRUISE_ID', 'VISIT_ID',
#        'STATION_ID', 'STN_DEPTH_M', 'LATITUDE', 'LONGITUDE', 'SAMPLING_DATE',
#        'TIME_ZONE', 'SAMPLE_DEPTH_M', 'DEPTH_CODE', 'MEDIUM', 'SAMPLE_TYPE',
#        'QC_TYPE', 'SAMPLE_ID', 'ANL_CODE_1', 'ANALYTE_1', 'VALUE_1', 'UNITS_1',
#        'FRACTION_1', 'METHOD_1', 'RESULT_REMARK_1', 'ANL_CODE_2', 'ANALYTE_2',
#        'VALUE_2', 'UNITS_2', 'FRACTION_2', 'METHOD_2', 'RESULT_REMARK_2',
#        'Unnamed: 33'],
#       dtype='object')

# %%
df['MONTH'].unique()
# Out:
# array(['April    ', 'August   ', 'May      ', 'October  ', 'December ',
#        'November ', 'March    '], dtype=object)

# %%
df[df['MONTH']=='April    ']
# Out:
#        Row  YEAR      MONTH  SEASON  LAKE  CRUISE_ID                VISIT_ID  \
# 0        1  2000  April      Spring  Erie     SP2000                 E015A00
# 1        2  2000  April      Spring  Erie     SP2000                 E010A00
# 2        3  2000  April      Spring  Erie     SP2000                 E063A00
# 3        4  2000  April      Spring  Erie     SP2000                 E015A00
# 4        5  2000  April      Spring  Erie     SP2000                 E010A00
# 5        6  2000  April      Spring  Erie     SP2000                 E009A00
# 6        7  2000  April      Spring  Erie     SP2000                 E009A00
# 7        8  2000  April      Spring  Erie     SP2000                 E063A00
# 8        9  2000  April      Spring  Erie     SP2000                 E063A00
# 9       10  2000  April      Spring  Erie     SP2000                 E063A00
# 10      11  2000  April      Spring  Erie     SP2000                 E063A00
# ...

# %%
sns.set_style('whitegrid')
sns.kdeplot(df[df['MONTH']=='August   '].VALUE_1.convert_objects(convert_numeric=True).values, bw='scott', label='August')
sns.kdeplot(df[df['MONTH']=='April    '].VALUE_1.convert_objects(convert_numeric=True).values, bw='scott', label='April')
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:454: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:454: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X>clip[0], X<clip[1])] # won't work for two columns.
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()
