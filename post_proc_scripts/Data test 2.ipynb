# %%
# %matplotlib inline
# %matplotlib notebook
# %matplotlib nbagg
import statsmodels.formula.api as sm

# %%
# %matplotlib inline
from ploting import *

# %%
df = plot_subplots_for_river_inputs('Western', 'riverraisin', method=plot_all_years_graph_in_ax_of_subplot)
# Out:
# Western basin, Riverraisin
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py:126: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df = df.convert_objects(convert_numeric=True)

# %%
df = plot_all_rivers_in_single_plot()
# Out:
# /Users/MarkelovIgor/git/biogeochemistry/Lake_Erie/post_proc_scripts/ploting.py:126: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df = df.convert_objects(convert_numeric=True)
