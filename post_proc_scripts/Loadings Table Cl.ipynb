# %%
import pandas as pd

# %%
print(pd.read_csv('/Users/imarkelo/Google Drive/GDocuments/Lake Erie/Draft/Rivers_tables_chloride/Total loads Cl.csv').round(1).to_latex())
# Out:
# \begin{tabular}{lllllllllllllllllll}
# \toprule
# {} &      Unnamed: 0 &    Unnamed: 1 &                 Unnamed: 2 &         2003 &         2004 &         2005 &         2006 &         2007 &         2008 &         2009 &         2010 &         2011 &         2012 &         2013 &         2014 &         2015 &         2016 &         2017 \\
# \midrule
# 0  &  St Clair Basin &            US &                    Clinton &      58,823  &      84,281  &      88,966  &     101,136  &     100,623  &      99,464  &     132,394  &      80,726  &     101,642  &      80,544  &      81,428  &      79,706  &      71,806  &      71,535  &      86,769  \\
# 1  &  St Clair Basin &            US &                      Belle &       5,130  &       5,130  &       5,130  &       5,130  &       5,130  &       5,130  &      12,902  &       3,104  &       4,529  &       5,391  &       4,502  &       2,972  &       3,677  &       4,580  &       4,516  \\
# ...
