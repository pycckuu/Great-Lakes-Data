# %%
import pandas as pd

# %%
glni = pd.read_excel('../../measurements/GLNI/Canadian_Tributaries_concentrations_Serghei.xlsx', sheet_name='Data_GLNI_Erie tribs')

# %%
glni.columns
# Out:
# Index(['ProjectCode', 'SiteCode', 'SiteName', 'Latitude', 'Longitude',
#        'IDCODE', 'SampleName(UserCode)', 'SampleAlias(UserCode2)',
#        'SampleDateTime', 'SampleDateTimeEnd', 'SampleQaTypeCode', 'VMVCode',
#        'VariableCommonName', 'VariableScientificName', 'Flag', 'Value',
#        'SampleDetectionLimit', 'MethodDetectionLimit',
#        'VMVMethodDetectionLimit', 'Unit', 'SampleQaTypeDesc',
#        'SampleMatrixCode', 'SampleMatrixDesc', 'LabSampleCode', 'LabCode',
#        'LabName', 'VariableTypeId', 'VariableType', 'ValidationLevels_id',
#        'ValidationLevel', 'Validity', 'Qualifiers', 'DRC_DataReleasesCode',
#        'DRC_QATypeCode', 'RDC_DateRgCode', 'DRC_SiteCode',
#        'DRC_ValidationLevelCode', 'DRC_ValidityCode', 'DRC_VMVCode',
#        'DRC_QualCode', 'SampleComment', 'MeasComment', 'PearseDACODE',
#        'PearseDA', 'Measurements_id'],
#       dtype='object')

# %%
df['VariableCommonName'].unique()
# Out:
# array(['Nitrogen total', 'Chlorophyll corrected', 'Chlorophyll A',
#        'Specific conductance', 'Carbon dissolved organic',
#        'Carbon particulate organic', 'Nitrogen Kjeldahl total',
#        'Nitrogen particulate', 'SiO2', 'Phosphorus total',
#        'Phosphorus total filtered', 'Carbon dissolved inorganic',
#        'Phosphorus soluble reactive', 'Nitrite and nitrate filtered',
#        'Ammonia filtered',
#        'Total suspended solids (non-filterable residue)',
#        'Chloride dissolved', 'Phosphorus particulate', 'Turbidity',
#        'Nitrogen total dissolved', 'Phosphorus total dissolved',
#        'Silica soluble reactive'], dtype=object)

# %%
df = glni[glni['SiteName'] == 'Big Creek near Walsingham']

elem = 'Phosphorus total'
TP = df[df['VariableCommonName'] == elem][['SampleDateTime','Value', 'Unit']]

elem = 'Nitrogen total'
TN = df[df['VariableCommonName'] == elem][['SampleDateTime','Value', 'Unit']]
TN

elem = 'Nitrogen Kjeldahl total'
NK = df[df['VariableCommonName'] == elem][['SampleDateTime','Value', 'Unit']]
NK

elem = 'Nitrite and nitrate filtered'
NO32 = df[df['VariableCommonName'] == elem][['SampleDateTime','Value', 'Unit']]
NO32

elem = 'Ammonia filtered'
NH4 = df[df['VariableCommonName'] == elem][['SampleDateTime','Value', 'Unit']]
NH4
# Out:
#            SampleDateTime  Value  Unit
# 122   2011-11-16 12:00:00  0.005  mg/L
# 179   2011-11-16 12:00:00  0.005  mg/L
# 282   2011-11-28 12:00:00  0.019  mg/L
# 402   2011-11-28 12:00:00  0.018  mg/L
# 562   2011-11-30 12:00:00  0.030  mg/L
# 682   2011-11-30 12:00:00  0.029  mg/L
# 802   2011-12-05 12:00:00  0.032  mg/L
# 922   2011-12-05 12:00:00  0.032  mg/L
# 1041  2011-12-12 12:00:00  0.051  mg/L
# 1155  2011-12-12 12:00:00  0.047  mg/L
# 1307  2011-12-19 12:00:00  0.040  mg/L
# 1417  2012-01-09 12:00:00  0.035  mg/L
# 1553  2012-01-16 12:00:00  0.042  mg/L
# 1764  2012-01-23 12:00:00  0.044  mg/L
# 1924  2012-01-31 12:00:00  0.032  mg/L
# 2084  2012-02-06 12:00:00  0.030  mg/L
# 2253  2012-02-06 12:00:00  0.024  mg/L
# 2424  2012-02-13 12:00:00  0.047  mg/L
# 2595  2012-02-21 12:00:00  0.030  mg/L
# 2762  2012-02-28 12:00:00  0.022  mg/L
# 2932  2012-03-05 12:00:00  0.031  mg/L
# 3110  2012-03-12 12:00:00  0.010  mg/L
# 3275  2012-03-12 12:00:00  0.011  mg/L
# ...
