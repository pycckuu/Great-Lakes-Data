# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# %%
pwqmn_rawdata_1964_1999 = pd.read_csv('../../measurements/PWQMN/pwqmn_rawdata_1964_1999/out.csv')
# Out:
# /Users/imarkelo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (5,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pwqmn_rawdata_1964_1999.shape
# Out:
# (4370806, 12)

# %%
pwqmn_rawdata_1964_1999[pwqmn_rawdata_1964_1999['STATION'] == 15000200202]
# Out:
#              STATION PARAM_CODE                      PARAMETER  \
# 143483   15000200202     NNHTFR  AMMONIUM, TOTAL   FILTER.REAC
# 340332   15000200202     NNO2FR    NITRITE,  FILTERED REACTIVE
# 748684   15000200202     NNOTFR  NITRATES TOTAL,   FILTER.REAC
# 947821   15000200202     NNTKUR  NITROGEN,TOT,KJELDAHL/UNF.REA
# 1295382  15000200202       PPUT    PHOSPHORUS,UNFILTERED TOTAL
# 1562254  15000200202        RSP            RESIDUE,PARTICULATE
# 1714360  15000200202        DIC    CARBON, DISSOLVED INORGANIC
# 1785480  15000200202      HARDT              HARDNESS,   TOTAL
# 1882139  15000200202       HGUT     MERCURY,  UNFILTERED TOTAL
# 2873691  15000200202       PBUT     LEAD,     UNFILTERED TOTAL
# 3497314  15000200202       ALKT              ALKALINITY, TOTAL
# 3836542  15000200202       CDUT      CADMIUM, UNFILTERED TOTAL
# 4004428  15000200202     CLIDUR   CHLORIDE,         UNFIL.REAC
# 4268877  15000200202     COND25              CONDUCTIVITY, 25C
# ...

# %%
pwqmn_rawdata_1964_1999.head()
# Out:
#        STATION PARAM_CODE                      PARAMETER               DATE  \
# 0   6011200102     NNHTFR  AMMONIUM, TOTAL   FILTER.REAC  01/21/65 00:00:00
# 1   6011600102     NNHTFR  AMMONIUM, TOTAL   FILTER.REAC  01/21/65 00:00:00
# 2   6011700102     NNHTFR  AMMONIUM, TOTAL   FILTER.REAC  01/21/65 00:00:00
# 3   6011800102     NNHTFR  AMMONIUM, TOTAL   FILTER.REAC  01/21/65 00:00:00
# 4  16009700102     NNHTFR  AMMONIUM, TOTAL   FILTER.REAC  01/26/65 00:00:00
#
#    TIME FIELD_NO  RESULT_VALUE VALUE_QUALIFIER REMARK_CODE1 REMARK_CODE  \
# 0   0.0    20499           0.1             NaN          NaN         000
# 1   0.0    20118           1.8             NaN          NaN         000
# 2   0.0    21471           0.1             NaN          NaN         000
# 3   0.0    20367           0.1             NaN          NaN         000
# 4   0.0    20168           0.3             NaN          NaN         000
#
#   ANAL_METH                UNITS
# 0      000A  MILLIGRAM PER LITER
# ...

# %%
pwqmn_rawdata_1964_1999['DATE'] = pd.to_datetime(pwqmn_rawdata_1964_1999['DATE'])

# %%
pwqmn_rawdata_1964_1999[(pwqmn_rawdata_1964_1999['DATE'].dt.year > 1995) & (pwqmn_rawdata_1964_1999['DATE'].dt.year < 2000)].to_csv("pwqmn_rawdata_1996_1999.csv")

# %%
pwqmn_rawdata_1964_1999['DATE'].dt.year.unique()
# Out:
# array([2065, 2064, 1975, 2066, 2067, 1968, 1969, 1970, 1971, 1972, 1973,
#        1974, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985,
#        1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996,
#        1997, 1998, 1999])
