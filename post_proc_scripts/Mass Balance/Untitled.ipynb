# %%
# libraries
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
import shapefile as shp  # Requires the pyshp package
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6), dpi=300)
m = Basemap(width=500000*0.8,height=300000*0.8, resolution='i',projection='stere',lat_0=42.0+0.2,lon_0=-81.0-0.2)
m.drawcoastlines()
# # m.drawstates()
m.drawrivers(color='dodgerblue',linewidth=1.0,zorder=1)
m.drawparallels(np.arange(41., 44, 1.),labels=[1,0,0,0], fontsize=10)
m.drawmeridians(np.arange(-84., -78., 1.),labels=[0,0,1,0], fontsize=10)

fname = r'/Users/imarkelo/git/Great-Lakes-Data/measurements/bathymetry/ne_10m_rivers_lake_centerlines/ne_10m_rivers_lake_centerlines.shp'
sf = shp.Reader(fname)

# plt.figure()
for shape in sf.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y, c='blue', zorder=1)

# %%
lat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-92571bde2a1d> in <module>
# ----> 1 lat
#
# NameError: name 'lat' is not defined

# %%
lat_0=42.0+0.2,lon_0=-81.0-0.2

# %%
import folium


m = folium.Map(location=[42.0+0.2,-81.0-0.2], zoom_start=8)

# folium.TileLayer('Mapbox Bright').add_to(m)
folium.TileLayer('cartodbpositron').add_to(m)
# folium.TileLayer('stamentoner').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature
import cartopy as cc

rivers = cartopy.feature.NaturalEarthFeature(
    category='physical', name='rivers_lake_centerlines',
    scale='110m', facecolor='none', edgecolor='blue')

fig, ax = plt.subplots(
    nrows=1, ncols=1, subplot_kw={'projection': ccrs.PlateCarree()},
                         figsize=(10,6))
ax.add_feature(rivers, linewidth=1)
ax.set_extent([-78.5, -83.5, 41, 43.3])


# shp_path = cc.io.shapereader.natural_earth(
#         resolution='10m',
#         category='physical',
#         name='rivers_lake_centerlines')
# shp_contents = cc.io.shapereader.Reader(shp_path)
# river_generator = shp_contents.geometries()
# river_feature = cc.feature.ShapelyFeature(
#         river_generator,
#         cc.crs.PlateCarree(),
#         edgecolor='blue',
#         facecolor='none')
# ax.add_feature(river_feature)

# import cartopy.feature as cfeature

# land_50m = cfeature.NaturalEarthFeature('physical', 'rivers', '1m',
#                                         edgecolor='face',
#                                         facecolor=cfeature.COLORS['water'])


# ax.add_feature(cartopy.feature.LAKES, alpha=0.5)
# ax.add_feature(cartopy.feature.RIVERS)
# ax.add_feature(land_50m)

# lat_0=42.0+0.2,lon_0=-81.0-0.2

plt.show()
# Out:
# Invalid argument (must be a Polygon)

# %%
cartopy.feature.RIVERS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-652a15c51a26> in <module>
# ----> 1 cartopy.feature.RIVERS
#
# NameError: name 'cartopy' is not defined

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.io.shapereader import Reader
from cartopy.feature import ShapelyFeature



ax = plt.axes(projection=ccrs.Robinson())
shape_feature = ShapelyFeature(Reader(fname).geometries(),
                                ccrs.PlateCarree(), edgecolor='black')
ax.add_feature(shape_feature)
plt.show()
# Out:
# Geometry must be a Point or LineString

# %%
import shapefile as shp  # Requires the pyshp package
import matplotlib.pyplot as plt

fname = r'/Users/imarkelo/git/Great-Lakes-Data/measurements/bathymetry/ne_10m_rivers_lake_centerlines_scale_rank/ne_10m_rivers_lake_centerlines_scale_rank.shp'
sf = shp.Reader(fname)

plt.figure()
for shape in sf.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y, c='blue')
plt.show()

# %%
shape
