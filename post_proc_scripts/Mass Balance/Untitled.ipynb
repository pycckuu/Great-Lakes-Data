# %%
# libraries
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
# A basic map
m=Basemap(llcrnrlon=-160, llcrnrlat=-75,urcrnrlon=160,urcrnrlat=80)
m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m.fillcontinents(color='grey', alpha=0.7, lake_color='grey')
m.drawcoastlines(linewidth=0.1, color="white")
 
# Add a marker per city of the data frame!
m.plot(data['lat'], data['lon'], linestyle='none', marker="o", markersize=16, alpha=0.6, c="orange", markeredgecolor="black", markeredgewidth=1)

# %%
plt.figure(figsize=(12,6), dpi=300)
m = Basemap(width=500000*0.8,height=300000*0.8, resolution='h',projection='stere',lat_0=42.0+0.2,lon_0=-81.0-0.2)
m.drawcoastlines()
m.drawparallels(np.arange(41., 44, 1.),labels=[1,0,0,0], fontsize=10)
m.drawmeridians(np.arange(-84., -78., 1.),labels=[0,0,1,0], fontsize=10)
# Out:
# {-83.0: ([<matplotlib.lines.Line2D at 0x1141017f0>],
#   [Text(54400,244000,'83°W')]),
#  -82.0: ([<matplotlib.lines.Line2D at 0x113e4e0b8>],
#   [Text(135600,244000,'82°W')]),
#  -81.0: ([<matplotlib.lines.Line2D at 0x113e4e4e0>],
#   [Text(216400,244000,'81°W')]),
#  -80.0: ([<matplotlib.lines.Line2D at 0x113e4e908>],
#   [Text(297200,244000,'80°W')]),
#  -79.0: ([<matplotlib.lines.Line2D at 0x113e4ed30>],
#   [Text(378400,244000,'79°W')])}
